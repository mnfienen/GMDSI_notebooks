# %% [markdown]
# # A deeper dive into the Gauss-Levenberg-Marquardt (GLM) algorithm: weights and noise
#
# The Gauss-Levenberg-Marquart (GLM) method is a gradient-based method used to search the objective function surface for its minimum value. It assumes that simulated values of observation targets vary continuously in response to changes in calibration-adjusted model parameters.  Two critical aspects of using ensemble-forms of GLM are how weights and observation noise are specified.  We will do this using the response surface of a simple 2-parameter form of the freyberg model
#
# This notebook builds on the previous response-surface notebook - check it out for a discussion of the GLM lambda in the context of response surfaces...

# %% [markdown]
# ### Admin
# We have provided some pre-cooked PEST dataset files, wrapped around the modified Freyberg model. This is the same dataset introduced in the "freyberg_pest_setup" and "freyberg_k" notebooks.
#
# The functions in the next cell import required dependencies and prepare a folder for you. This folder contains the model files and a preliminary PEST setup. Run the cells, then inspect the new folder named "freyberg_mf6" which has been created in your tutorial directory. (Just press `shift+enter` to run the cells).

# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt;
import shutil

# sys.path.insert(0,os.path.join("..", "..", "dependencies"))
import pyemu
import flopy
assert "dependencies" in flopy.__file__
assert "dependencies" in pyemu.__file__
sys.path.insert(0,"..")
import herebedragons as hbd
import response_surface_OFR as resurf

plt.rcParams['font.size'] = 10
pyemu.plot_utils.font =10

run_response_surfaces = False

# %% [markdown]
# Here we prep for the response surface runs:

# %%
# folder containing original model files
org_d = os.path.join('..', '..', 'models', 'monthly_model_files_1lyr_newstress')
# a dir to hold a copy of the org model files
tmp_d = os.path.join('freyberg_mf6')

if os.path.exists(tmp_d):
    shutil.rmtree(tmp_d)
shutil.copytree(org_d,tmp_d)
# get executables
hbd.prep_bins(tmp_d)
# get dependency folders
hbd.prep_deps(tmp_d)
# run our convenience functions to prepare the PEST and model folder
hbd.prep_pest(tmp_d)
# Out:
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 07/30/2021
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Dec 29 2021 09:30:50 with Intel(R) Fortran Intel(R) 64
#    Compiler for applications running on Intel(R) 64, Version 19.1.3.301 Build
#                                 20200925_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/01/30 17:15:25
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/01/30 17:15:25
#  Elapsed run time:  0.765 Seconds
#
#  Normal termination of simulation.
#
# MODPATH Version 7.2.001
# Program compiled Aug 01 2021 12:57:00 with IFORT compiler (ver. 19.10.3)
#
#
# Run particle tracking simulation ...
# Processing Time Step     1 Period     1.  Time =  3.65250E+03  Steady-state flow
# Processing Time Step     1 Period     2.  Time =  3.68350E+03  Steady-state flow
# Processing Time Step     1 Period     3.  Time =  3.71250E+03  Steady-state flow
# Processing Time Step     1 Period     4.  Time =  3.74350E+03  Steady-state flow
# Processing Time Step     1 Period     5.  Time =  3.77350E+03  Steady-state flow
# Processing Time Step     1 Period     6.  Time =  3.80450E+03  Steady-state flow
# Processing Time Step     1 Period     7.  Time =  3.83450E+03  Steady-state flow
# Processing Time Step     1 Period     8.  Time =  3.86550E+03  Steady-state flow
# Processing Time Step     1 Period     9.  Time =  3.89650E+03  Steady-state flow
# Processing Time Step     1 Period    10.  Time =  3.92650E+03  Steady-state flow
# Processing Time Step     1 Period    11.  Time =  3.95750E+03  Steady-state flow
# Processing Time Step     1 Period    12.  Time =  3.98750E+03  Steady-state flow
# Processing Time Step     1 Period    13.  Time =  4.01850E+03  Steady-state flow
# Processing Time Step     1 Period    14.  Time =  4.04950E+03  Steady-state flow
# Processing Time Step     1 Period    15.  Time =  4.07750E+03  Steady-state flow
# Processing Time Step     1 Period    16.  Time =  4.10850E+03  Steady-state flow
# Processing Time Step     1 Period    17.  Time =  4.13850E+03  Steady-state flow
# Processing Time Step     1 Period    18.  Time =  4.16950E+03  Steady-state flow
# Processing Time Step     1 Period    19.  Time =  4.19950E+03  Steady-state flow
# Processing Time Step     1 Period    20.  Time =  4.23050E+03  Steady-state flow
# Processing Time Step     1 Period    21.  Time =  4.26150E+03  Steady-state flow
# Processing Time Step     1 Period    22.  Time =  4.29150E+03  Steady-state flow
# Processing Time Step     1 Period    23.  Time =  4.32250E+03  Steady-state flow
# Processing Time Step     1 Period    24.  Time =  4.35250E+03  Steady-state flow
# Processing Time Step     1 Period    25.  Time =  4.38350E+03  Steady-state flow
#
# Particle Summary:
#          0 particles are pending release.
#          0 particles remain active.
#          0 particles terminated at boundary faces.
#          0 particles terminated at weak sink cells.
#          0 particles terminated at weak source cells.
#          1 particles terminated at strong source/sink cells.
#          0 particles terminated in cells with a specified zone number.
#          0 particles were stranded in inactive or dry cells.
#          0 particles were unreleased.
#          0 particles have an unknown status.
#
# Normal termination.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file heads.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file heads.csv ----->
#  No errors encountered.
#
#  325 observations identified in file heads.csv.ins: these are listed in file
#    heads.csv.obf together with their values as read from file heads.csv.
#
# ins file for heads.csv prepared.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file sfr.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file sfr.csv ----->
#  No errors encountered.
#
#  75 observations identified in file sfr.csv.ins: these are listed in file
#    sfr.csv.obf together with their values as read from file sfr.csv.
#
# ins file for sfr.csv prepared.
# noptmax:0, npar_adj:1, nnz_obs:24
# written pest control file: freyberg_mf6/freyberg.pst

# %% [markdown]
# ### Reminder - the modified-Freyberg model
# Just a quick reminder of what the model looks like and what we are doing.
#
# It is a one-layer model. A river runs north-south, represented with the SFR package (green cells in the figure). On the southern border there is a GHB (cyan cells). No-flow cells are shown in black. Pumping wells are shown with red cells.
#
# Time-series of measured heads are available at the locations marked with black X's. River flux is also measured at three locations (headwater, tailwater and gage; not displayed).
#
# The simulation starts with a steady state stress period, followed by twelve transient stress periods. These represent the historic period, for which measured data are available.
#
# A subsequent twelve transient stress periods representing a period in the future. Modelling is undertaken to assess selected forecasts during the simulated period.

# %%
hbd.plot_freyberg(tmp_d)

# %% [markdown]
# ### The PEST Control File
#
# You may  wish to explore the `freyberg_mf6` folder which has been created in the tutorial directory. In it you will find a PEST control file named `freyberg.pst`.
#
# Let's use `pyemu` to load the PEST control file and check some details.

# %%
pst = pyemu.Pst(os.path.join(tmp_d, 'freyberg.pst'))
pst.par_names
# Out:
# ['hk1', 'ne1', 'rch0', 'rch1']

# %%
par = pst.parameter_data
par
# Out:
#        parnme partrans parchglim  parval1  parlbnd  parubnd     pargp  scale  \
# parnme
# hk1       hk1      log    factor     5.00    0.050   500.00        hk    1.0
# ne1       ne1    fixed    factor     0.01    0.005     0.02  porosity    1.0
# rch0     rch0    fixed    factor     1.00    0.500     2.00      rch0    1.0
# rch1     rch1    fixed    factor     1.00    0.500     2.00      rch1    1.0
#
#         offset  extra  dercom
# parnme
# hk1        0.0    NaN     1.0
# ne1        0.0    NaN     1.0
# rch0       0.0    NaN     1.0
# rch1       0.0    NaN     1.0

# %% [markdown]
# We shall explore the effect of having two adjustable parameters: `hk1` and `rch0`. As we saw in the previous response surface notebook, with just groundwater level observations, these two parameters are strongly correlated in the objective function. If we use only head observations for calibration we are unable to achive a unique solution.
#
# (We shall change `hk1` parameter bounds just to make visualization easier.)

# %%
par.loc['rch0', 'partrans'] = 'log'
par.loc['hk1', 'parlbnd'] = 1.5
par.loc['hk1', 'parubnd'] = 15

# %% [markdown]
# Re-write the control file:

# %%
pst.write(os.path.join(tmp_d, 'freyberg.pst'),version=2)
# Out:
# noptmax:0, npar_adj:2, nnz_obs:24

# %% [markdown]
# The `response_surface.py` file in the tutorial folder contains a few functions to run `PESTPP-SWP` and make plots. These run `PESTPP-SWP` a few hundred times for a combination of `hk1` and `rch0` values.

# %%
num_workers = 25

# %% [markdown]
# ### Add Flux Observations
#
# As we did in the previous response surface notebook, we know that if we add measurments of stream flow, we break that correlation, so let's do that here too:

# %%
pst = pyemu.Pst(os.path.join(tmp_d, 'freyberg.pst'))

# %%
# set weights to gage-1 observations during calibration period
obs = pst.observation_data
obs.loc[:,"observed"] = False

obs_times = obs.loc[~obs['gage-1'].isnull(), 'gage-1'].astype(float).values
calib_times = [str(i) for i in obs_times if i<4018.5]
obs.loc[obs['gage-1'].isin(calib_times), 'weight'] = 0.003 # we know from our own experiments this is a good, error-based value that creates a balanced objective function...
obs.loc[obs.weight > 0,"observed"] = True

# %% [markdown]
# Re-write the control file.

# %%
pst.write(os.path.join(tmp_d, 'freyberg.pst'),version=2)
# Out:
# noptmax:0, npar_adj:2, nnz_obs:36

# %% [markdown]
# Run PESTPP-SWP to calculate the response surface.

# %%
org_resp_d = "resp_weight1"
if run_response_surfaces:
    if os.path.exists(org_resp_d):
        shutil.rmtree(org_resp_d)
    shutil.copytree(tmp_d,org_resp_d)
    resurf.run_respsurf(par_names=['hk1','rch0'],num_workers=num_workers,port=4269,WORKING_DIR=org_resp_d)

# %% [markdown]
# And plot it up. As expected, we see the objective function surface funneling down to a single closed "region of attraction". We have achieved a unique solution.

# %%
fig, ax, resp_surf = resurf.plot_response_surface(cmap='jet', figsize=(7,7),WORKING_DIR=org_resp_d) #maxresp=1e3,

# %% [markdown]
# ### Understanding how weights change the response surface (and the result!)
#
# A critical point in all of this: The weights assigned to the observations define the shape of the objective function (likelihood) function - note: herein, we refer to this as the response surface. The extreme example of this is adding observations.  But even just changing the weights between obserations also changes things.  To see this, lets the weights of the surface-water flux observations to a much higher proportion of the composite objective function (and while we are it, lets also make those surface-water flux observation weights a function of the observed value so that large flux values have lower weight):

# %%
obs = pst.observation_data
obs_times = obs.loc[~obs['gage-1'].isnull(), 'gage-1'].astype(float).values
calib_times = [str(i) for i in obs_times if i<4018.5]
ovals = obs.loc[obs['gage-1'].isin(calib_times), 'obsval']
obs.loc[obs['gage-1'].isin(calib_times), 'weight'] = 1./(ovals*0.01) #weight equals the inverse of 1% of the observed value
pst.write(os.path.join(tmp_d, 'freyberg.pst'),version=2)
mod_resp_d = "resp_weight2"
if run_response_surfaces:
    if os.path.exists(mod_resp_d):
        shutil.rmtree(mod_resp_d)
    shutil.copytree(tmp_d,mod_resp_d)
    resurf.run_respsurf(par_names=['hk1','rch0'],num_workers=num_workers,port=4269,WORKING_DIR=mod_resp_d)
# Out:
# noptmax:0, npar_adj:2, nnz_obs:36

# %%
fig, ax, resp_surf = resurf.plot_response_surface(cmap='jet', figsize=(7,7),WORKING_DIR=mod_resp_d) #maxresp=1e3,

# %% [markdown]
# Thats a pretty shocking difference, especially when we consider that this is a simple 2-D (ie 2-parameter) problem.  Whats more, the goal of our data assimilation analyses is to navigate this surface to the (region around the) minimum.  Let's see how changing the weights changes the parameter posterior distribution

# %% [markdown]
# ### Optional: choose your own adventure!
#
# Here you can form your own objective function by changing weights and see how that changes the response surface and also (later on down the notebook) see how it effects PESTPP-IES and ultimately, posterior forecast uncertainty

# %%
# here is an example where the value of low sw flow obs is amplied:

# obs = pst.observation_data
# for grp in pst.nnz_obs_groups:
#     if "gage" not in grp:
#         continue
#     oobs = obs.loc[obs.obgnme==grp,:]
#     oobs = oobs.loc[oobs.observed==True,:]
#     mn = oobs.obsval.mean()
#     lower_names = oobs.loc[oobs.obsval<mn,"obsnme"]
#     assert len(lower_names) > 0
#     obs.loc[lower_names,"weight"] = 100

# pst.write(os.path.join(tmp_d, 'freyberg.pst'),version=2)
# mod_resp_d = "resp_weight2"

# if os.path.exists(mod_resp_d):
#    shutil.rmtree(mod_resp_d)
# shutil.copytree(tmp_d,mod_resp_d)
# resurf.run_respsurf(par_names=['hk1','rch0'],num_workers=num_workers,port=4269,WORKING_DIR=mod_resp_d)

# %%
fig, ax, resp_surf = resurf.plot_response_surface(cmap='jet', figsize=(7,7),WORKING_DIR=mod_resp_d) #maxresp=1e3,

# %% [markdown]
# # Understanding how weights change results

# %% [markdown]
# This function just makes sure we are consistently using the same pest interface settings...

# %%
def prep_pst(t_d="template",noptmax=6):
    if os.path.exists(t_d):
        shutil.rmtree(t_d)
    shutil.copytree(org_d,t_d)
    # get executables
    hbd.prep_bins(t_d)
    # get dependency folders
    hbd.prep_deps(t_d)
    # run our convenience functions to prepare the PEST and model folder
    hbd.prep_pest(t_d)
    pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
    obs = pst.observation_data
    obs_times = obs.loc[~obs['gage-1'].isnull(), 'gage-1'].astype(float).values
    calib_times = [str(i) for i in obs_times if i<4018.5]
    obs.loc[obs['gage-1'].isin(calib_times), 'weight'] = 0.003
    #obs.loc[pst.nnz_obs_names,"standard_deviation"] = 10. / obs.loc[pst.nnz_obs_names,"weight"]
    
    par = pst.parameter_data
    par.loc['rch0', 'partrans'] = 'log'
    par.loc['hk1', 'parlbnd'] = 1.5
    par.loc['hk1', 'parubnd'] = 15
    
    par.loc[pst.adj_par_names,"partrans"] = "none"
    par.loc[pst.adj_par_names,"parval1"] = (par.loc[pst.adj_par_names,"parlbnd"] + par.loc[pst.adj_par_names,"parubnd"]) / 2.0
    
    pst.control_data.noptmax = noptmax
    pst.write(os.path.join(t_d,"freyberg.pst"),version=2)

# %% [markdown]
# Here is a nasty plotting function - just ignore it!

# %%
def plot_ies_and_resp_par_forecast_results(resp_d,ies_d):
    r_inp = pd.read_csv(os.path.join(resp_d,"freybergsweep_in.csv"),index_col=0)
    r_out = pd.read_csv(os.path.join(resp_d,"freybergsweep_out.csv"),index_col=1)
    r_out.loc[:,"likelihood"] = 1.0/r_out.phi.values**2
    phidf = pd.read_csv(os.path.join(ies_d,"freyberg.phi.actual.csv"))
    iiter = int(phidf.iteration.max())
    print("using iter",iiter)
    pe = pd.read_csv(os.path.join(ies_d,"freyberg.{0}.par.csv".format(iiter)),index_col=0)
    oe_pt = pd.read_csv(os.path.join(ies_d,"freyberg.{0}.obs.csv".format(iiter)),index_col=0)
    oe_pr = pd.read_csv(os.path.join(ies_d,"freyberg.0.obs.csv"),index_col=0)
    r_inp.loc[:,"phi"] = r_out.likelihood
    
    
    

    fig1, ax1, resp_surf = resurf.plot_response_surface(cmap='jet', figsize=(7,7),WORKING_DIR=resp_d) #maxresp=1e3,
    pes = []
    for i in range(iiter+1):
        fname = os.path.join(ies_d,"freyberg.{0}.par.csv".format(i))
        if not os.path.exists(fname):
            break
        pe = pd.read_csv(fname,index_col=0)    
        pes.append(pe)
    for real in pes[-1].index:
        xvals  = [pe.loc[real,"hk1"] for pe in pes]
        yvals  = [pe.loc[real,"rch0"] for pe in pes]
        ax1.plot(xvals,yvals,marker=".",c="0.5",lw=0.5)
    xvals = pes[-1].loc[:,"hk1"].values
    yvals = pes[-1].loc[:,"rch0"].values
    ax1.scatter(xvals,yvals,marker=".",c="b",zorder=10)
    plt.savefig('iesplot.pdf', dpi=500
    )
    plt.show()

    fig,axes = plt.subplots(2,1,figsize=(6,6))
    hk1 = r_inp.groupby("hk1").sum().loc[:,"phi"]
    rch0 = r_inp.groupby("rch0").sum().loc[:,"phi"]
    hk1_space = hk1.index[1] - hk1.index[0]
    rch0_space = rch0.index[1] - rch0.index[0]
    axes[0].bar(hk1.index,hk1.values,width=hk1_space,alpha=0.1,fc="0.5")
    axes[1].bar(rch0.index,rch0.values,width=rch0_space,alpha=0.1,fc="0.5")
    axt0 = plt.twinx(axes[0])
    axt0.hist(pe.loc[:,"hk1"].values,density=True,alpha=0.5,fc="b")
    axt1 = plt.twinx(axes[1])
    axt1.hist(pe.loc[:,"rch0"].values,density=True,alpha=0.5,fc="b")
    axes[0].set_title("hk1",loc="left")
    axes[1].set_title("rch0",loc="left")
    for ax in [axes[0],axes[1],axt0,axt1]:
        ax.set_yticks([])
    
    for forecast in pst.pestpp_options["forecasts"].split(","):
        fig,ax = plt.subplots(1,1,figsize=(6,3))
        #ax.hist(r_out.loc[:,forecast].values,weights=r_out.likelihood.values,alpha=0.5,fc="0.5",density=True)
        ax.hist(oe_pr.loc[:,forecast].values,alpha=0.5,fc="0.5",density=True)
        ax.hist(oe_pt.loc[:,forecast].values,alpha=0.5,fc="b",density=True)
        ax.set_yticks([])
        ax.set_title(forecast,loc="left")
        ylim = ax.get_ylim()
        #fval = pst.observation_data.loc[forecast,"obsval"]
        #ax.plot([fval,fval],ylim,"r-",lw=2)
    return fig1,ax1

# %% [markdown]
# First let's run PESTPP-IES using the same weights as the original response surface above:

# %%
t_d = "template"
prep_pst(t_d=t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_orgweight"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
# Out:
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 07/30/2021
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Dec 29 2021 09:30:50 with Intel(R) Fortran Intel(R) 64
#    Compiler for applications running on Intel(R) 64, Version 19.1.3.301 Build
#                                 20200925_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/01/30 17:15:45
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/01/30 17:15:45
#  Elapsed run time:  0.907 Seconds
#
#  Normal termination of simulation.
#
# MODPATH Version 7.2.001
# Program compiled Aug 01 2021 12:57:00 with IFORT compiler (ver. 19.10.3)
#
#
# Run particle tracking simulation ...
# Processing Time Step     1 Period     1.  Time =  3.65250E+03  Steady-state flow
# Processing Time Step     1 Period     2.  Time =  3.68350E+03  Steady-state flow
# Processing Time Step     1 Period     3.  Time =  3.71250E+03  Steady-state flow
# Processing Time Step     1 Period     4.  Time =  3.74350E+03  Steady-state flow
# Processing Time Step     1 Period     5.  Time =  3.77350E+03  Steady-state flow
# Processing Time Step     1 Period     6.  Time =  3.80450E+03  Steady-state flow
# Processing Time Step     1 Period     7.  Time =  3.83450E+03  Steady-state flow
# Processing Time Step     1 Period     8.  Time =  3.86550E+03  Steady-state flow
# Processing Time Step     1 Period     9.  Time =  3.89650E+03  Steady-state flow
# Processing Time Step     1 Period    10.  Time =  3.92650E+03  Steady-state flow
# Processing Time Step     1 Period    11.  Time =  3.95750E+03  Steady-state flow
# Processing Time Step     1 Period    12.  Time =  3.98750E+03  Steady-state flow
# Processing Time Step     1 Period    13.  Time =  4.01850E+03  Steady-state flow
# Processing Time Step     1 Period    14.  Time =  4.04950E+03  Steady-state flow
# Processing Time Step     1 Period    15.  Time =  4.07750E+03  Steady-state flow
# Processing Time Step     1 Period    16.  Time =  4.10850E+03  Steady-state flow
# Processing Time Step     1 Period    17.  Time =  4.13850E+03  Steady-state flow
# Processing Time Step     1 Period    18.  Time =  4.16950E+03  Steady-state flow
# Processing Time Step     1 Period    19.  Time =  4.19950E+03  Steady-state flow
# Processing Time Step     1 Period    20.  Time =  4.23050E+03  Steady-state flow
# Processing Time Step     1 Period    21.  Time =  4.26150E+03  Steady-state flow
# Processing Time Step     1 Period    22.  Time =  4.29150E+03  Steady-state flow
# Processing Time Step     1 Period    23.  Time =  4.32250E+03  Steady-state flow
# Processing Time Step     1 Period    24.  Time =  4.35250E+03  Steady-state flow
# Processing Time Step     1 Period    25.  Time =  4.38350E+03  Steady-state flow
#
# Particle Summary:
#          0 particles are pending release.
#          0 particles remain active.
#          0 particles terminated at boundary faces.
#          0 particles terminated at weak sink cells.
#          0 particles terminated at weak source cells.
#          1 particles terminated at strong source/sink cells.
#          0 particles terminated in cells with a specified zone number.
#          0 particles were stranded in inactive or dry cells.
#          0 particles were unreleased.
#          0 particles have an unknown status.
#
# Normal termination.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file heads.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file heads.csv ----->
#  No errors encountered.
#
#  325 observations identified in file heads.csv.ins: these are listed in file
#    heads.csv.obf together with their values as read from file heads.csv.
#
# ins file for heads.csv prepared.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file sfr.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file sfr.csv ----->
#  No errors encountered.
#
#  75 observations identified in file sfr.csv.ins: these are listed in file
#    sfr.csv.obf together with their values as read from file sfr.csv.
#
# ins file for sfr.csv prepared.
# noptmax:0, npar_adj:1, nnz_obs:24
# written pest control file: template/freyberg.pst
# noptmax:6, npar_adj:2, nnz_obs:36
# noptmax:6, npar_adj:2, nnz_obs:36
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.6
# binary compiled on Aug 15 2023 at 16:48:53
#
# started at 01/30/24 17:15:48
# ...processing command line: ' ./pestpp-ies freyberg.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "freyberg.pst"
# in directory: "/Users/mnfienen/Documents/GIT/GMDSI_notebooks/tutorials/part1_06_glm_response_surface/master_orgweight"
# on host: "IGSACB116LHMNFI"
#
# processing control file freyberg.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
#
#   ---  sanity_check warnings  ---
# ...noptmax > 3, this is a lot of iterations for an ensemble method, please consider using fewer iterations for better outcomes
# ...continuing initialization...
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  50
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  50
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  freyberg.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  freyberg.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  freyberg.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 50
#     running model 50 times
#     starting at 01/30/24 17:15:48
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:16:23 mn:0.27  runs(C50   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    50 runs complete :  0 runs failed
#    0.266 avg run time (min) : 0.577 run mgr time (min)
#    25 agents connected
#
#
# ...saved initial obs ensemble to freyberg.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        324.206        243.775        84.6533        1119.67
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        324.206        243.775        84.6533        1119.67
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 1
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  1
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
# ...starting calcs for glm factor 10
# ...finished calcs for: 10
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  17:17, 21:21, 36:36, 49:BASE,
# ...subset idx:oe real name:  17:17, 21:21, 36:36, 49:BASE,
#     running model 36 times
#     starting at 01/30/24 17:16:24
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:16:33 mn:0.055 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0546 avg run time (min) : 0.147 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  324.206
# ...last stdev:  243.775
#
#   ---  phi summary for best lambda, scale fac: 10 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        61.3337        26.3888         38.356        99.3806
#          actual        34.6912        8.36577        24.2171        43.7366
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:10 , 1 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:16:33
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:16:42 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0507 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 10 , 1 ,
#        phi type           mean            std            min            max
#        measured        95.6765         34.976         38.356        197.139
#          actual        61.7556        31.1506        22.6107        136.887
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  340.416
# ...current best mean phi:  95.6765
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  7.5  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   50
#    number of model runs:            132
#       current obs ensemble saved to freyberg.1.obs.csv
#       current par ensemble saved to freyberg.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        95.6765         34.976         38.356        197.139
#          actual        61.7556        31.1506        22.6107        136.887
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            28.4      6.45      17.4      42.4      54.6      20.3
# trgw-0-3-8        16.9      15.4     0.486      53.5      22.3      14.8
# trgw-0-26-6       16.4      12.2      1.04        44      23.1      9.47
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     36        38         0         0         0         0      0.35      0.34
# rch0                   11        89         0         0         0         0      0.29     0.034
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 ,
# ...best phi yet:  95.6765
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  7.5
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
# ...starting calcs for glm factor 7.5
# ...finished calcs for: 7.5
# ...starting calcs for glm factor 75
# ...finished calcs for: 75
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 25:23, 26:24, 46:45,
# ...subset idx:oe real name:  3:BASE, 25:23, 26:24, 46:45,
#     running model 36 times
#     starting at 01/30/24 17:16:42
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:16:51 mn:0.056 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0556 avg run time (min) : 0.152 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  95.6765
# ...last stdev:  34.976
#
#   ---  phi summary for best lambda, scale fac: 0.75 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        67.5516        38.9464        22.9335        116.085
#          actual        35.2035        14.5561        22.6784        50.8269
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.75 , 0.75 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:16:51
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:01 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0514 avg run time (min) : 0.157 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.75 , 0.75 ,
#        phi type           mean            std            min            max
#        measured         70.879        21.7548        22.9335        152.591
#          actual        36.7763        19.3462        22.6784        106.286
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  100.46
# ...current best mean phi:  70.879
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.5625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   50
#    number of model runs:            214
#       current obs ensemble saved to freyberg.2.obs.csv
#       current par ensemble saved to freyberg.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured         70.879        21.7548        22.9335        152.591
#          actual        36.7763        19.3462        22.6784        106.286
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            23.1      4.05      17.8      36.2      71.1      18.2
# trgw-0-3-8        7.43      12.1     0.274      64.9      14.9        15
# trgw-0-26-6        6.2      6.67      1.02      28.8        14      8.39
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     54        68         0         0         0         0      0.35      0.25
# rch0                   11        91         0         0         0         0      0.29      0.03
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 , 70.879 ,
# ...best phi yet:  70.879
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.5625
# ...starting calcs for glm factor 0.05625
# ...finished calcs for: 0.05625
# ...starting calcs for glm factor 0.5625
# ...finished calcs for: 0.5625
# ...starting calcs for glm factor 5.625
# ...finished calcs for: 5.625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 9:2, 10:3, 41:39,
# ...subset idx:oe real name:  0:BASE, 9:2, 10:3, 41:39,
#     running model 36 times
#     starting at 01/30/24 17:17:01
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:09 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0514 avg run time (min) : 0.143 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  70.879
# ...last stdev:  21.7548
#
#   ---  phi summary for best lambda, scale fac: 0.5625 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        44.1302        14.4086        22.6217        52.4273
#          actual        25.4715        3.29715        22.6217        29.5653
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.5625 , 0.75 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:17:09
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:19 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0517 avg run time (min) : 0.156 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.5625 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        62.0325        13.7793        22.6217        91.9874
#          actual        27.7943        8.50383        22.6217        62.6194
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  74.4229
# ...current best mean phi:  62.0325
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.421875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   50
#    number of model runs:            296
#       current obs ensemble saved to freyberg.3.obs.csv
#       current par ensemble saved to freyberg.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        62.0325        13.7793        22.6217        91.9874
#          actual        27.7943        8.50383        22.6217        62.6194
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            21.6         3      17.3      31.7      80.4      11.8
# trgw-0-3-8        3.29      3.65     0.266      14.5      10.7       9.4
# trgw-0-26-6       2.92       3.8      1.02      18.7       8.9      6.33
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     58        81         0         0         0         0      0.35      0.16
# rch0                   11        91         0         0         0         0      0.29     0.029
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 , 70.879 , 62.0325 ,
# ...best phi yet:  62.0325
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 4  ---
# ...current lambda:  0.421875
# ...starting calcs for glm factor 0.0421875
# ...finished calcs for: 0.0421875
# ...starting calcs for glm factor 0.421875
# ...finished calcs for: 0.421875
# ...starting calcs for glm factor 4.21875
# ...finished calcs for: 4.21875
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 8:21, 12:4, 44:42,
# ...subset idx:oe real name:  0:BASE, 8:21, 12:4, 44:42,
#     running model 36 times
#     starting at 01/30/24 17:17:19
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:28 mn:0.052 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0516 avg run time (min) : 0.149 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  62.0325
# ...last stdev:  13.7793
#
#   ---  phi summary for best lambda, scale fac: 4.21875 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        47.5584        16.9331        22.5535        60.0124
#          actual        24.1834        1.60435        22.5535        26.3815
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:4.21875 , 1.1 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:17:28
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:37 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0521 avg run time (min) : 0.159 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 4.21875 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        60.6748        13.2733        22.5535        91.4421
#          actual        26.3224        5.95472        22.5505        49.0693
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  65.1342
# ...current best mean phi:  60.6748
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  3.16406  ---
#
#   ---  EnsembleMethod iteration 4 report  ---
#    number of active realizations:   50
#    number of model runs:            378
#       current obs ensemble saved to freyberg.4.obs.csv
#       current par ensemble saved to freyberg.4.par.csv
# saved par and rei files for realization BASE for iteration 4
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        60.6748        13.2733        22.5535        91.4421
#          actual        26.3224        5.95472        22.5505        49.0693
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            21.3      2.63      17.3      29.2      82.7      9.63
# trgw-0-3-8        2.61       2.5     0.266      11.2      9.41      7.67
# trgw-0-26-6       2.36      2.81      1.01      13.6       7.9      5.62
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     59        85         0         0         0         0      0.35      0.12
# rch0                   11        91         0         0         0         0      0.29     0.029
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.4.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 , 70.879 , 62.0325 , 60.6748 ,
# ...best phi yet:  60.6748
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 5  ---
# ...current lambda:  3.16406
# ...starting calcs for glm factor 0.316406
# ...finished calcs for: 0.316406
# ...starting calcs for glm factor 3.16406
# ...finished calcs for: 3.16406
# ...starting calcs for glm factor 31.6406
# ...finished calcs for: 31.6406
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 12:0, 31:26, 49:48,
# ...subset idx:oe real name:  0:BASE, 12:0, 31:26, 49:48,
#     running model 36 times
#     starting at 01/30/24 17:17:37
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:46 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0508 avg run time (min) : 0.148 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  60.6748
# ...last stdev:  13.2733
#
#   ---  phi summary for best lambda, scale fac: 0.316406 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        52.0058        21.5645        22.4877        70.0543
#          actual        24.0968         1.9396        22.4877        26.7244
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.316406 , 1.1 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:17:46
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:17:56 mn:0.054 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0537 avg run time (min) : 0.163 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.316406 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        60.0238        13.2527        22.4877         92.676
#          actual        25.5775        3.88281        22.4877        40.8346
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  63.7086
# ...current best mean phi:  60.0238
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.237305  ---
#
#   ---  EnsembleMethod iteration 5 report  ---
#    number of active realizations:   50
#    number of model runs:            460
#       current obs ensemble saved to freyberg.5.obs.csv
#       current par ensemble saved to freyberg.5.par.csv
# saved par and rei files for realization BASE for iteration 5
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        60.0238        13.2527        22.4877         92.676
#          actual        25.5775        3.88281        22.4877        40.8346
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1              21      2.45      17.3      27.5      82.9      8.59
# trgw-0-3-8        2.61      2.44     0.346        11       9.9      8.01
# trgw-0-26-6       1.97      1.75      1.01      10.3      7.24      4.47
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     59        89         0         0         0         0      0.35     0.092
# rch0                   11        91         0         0         0         0      0.29     0.029
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.5.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 , 70.879 , 62.0325 , 60.6748 , 60.0238 ,
# ...best phi yet:  60.0238
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 6  ---
# ...current lambda:  0.237305
# ...starting calcs for glm factor 0.0237305
# ...finished calcs for: 0.0237305
# ...starting calcs for glm factor 0.237305
# ...finished calcs for: 0.237305
# ...starting calcs for glm factor 2.37305
# ...finished calcs for: 2.37305
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 32:25, 36:30, 45:41,
# ...subset idx:oe real name:  0:BASE, 32:25, 36:30, 45:41,
#     running model 36 times
#     starting at 01/30/24 17:17:56
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:18:05 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0512 avg run time (min) : 0.143 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  60.0238
# ...last stdev:  13.2527
#
#   ---  phi summary for best lambda, scale fac: 0.237305 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        53.2577        27.7762        22.4871        89.8465
#          actual        24.3023        2.62233        22.4871        28.0849
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.237305 , 1.1 ,   ---
#     running model 46 times
#     starting at 01/30/24 17:18:05
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/30 17:18:14 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0522 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.237305 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        59.6782        13.0548        22.4871        89.8465
#          actual        25.1552        3.19884        22.4871        38.7501
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  63.025
# ...current best mean phi:  59.6782
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.177979  ---
#
#   ---  EnsembleMethod iteration 6 report  ---
#    number of active realizations:   50
#    number of model runs:            542
#       current obs ensemble saved to freyberg.6.obs.csv
#       current par ensemble saved to freyberg.6.par.csv
# saved par and rei files for realization BASE for iteration 6
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        59.6782        13.0548        22.4871        89.8465
#          actual        25.1552        3.19884        22.4871        38.7501
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1              21      2.48      17.4      27.8      83.9      7.14
# trgw-0-3-8        2.34         2     0.346      10.5       9.2      7.07
# trgw-0-26-6        1.8       1.4      1.01      9.13      6.86      3.86
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     60        91         0         0         0         0      0.35     0.079
# rch0                   11        91         0         0         0         0      0.29      0.03
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.6.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 324.206 , 95.6765 , 70.879 , 62.0325 , 60.6748 , 60.0238 , 59.6782 ,
#
# ...best phi yet:  59.6782
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#
# pestpp-ies analysis complete...
# started at 01/30/24 17:15:48
# finished at 01/30/24 17:18:17
# took 2.48333 minutes

# %%
fig1,ax = plot_ies_and_resp_par_forecast_results(org_resp_d,m_d)
ax.set_title(r'iES with min $\Phi$ = 23.08')
fig1.savefig('ies_resp_0.pdf', dpi=500)
# Out:
# using iter 6

# %% [markdown]
# GREAT SUCCESS!!!  Just what we wanted - each realization has a nice trajectory to the minimum of the misfit between simulated states and their observed counterparts.  Now, in the typical groundwater modeling approach, lets mess with this success and use the modified weights we used for the second response surface above:

# %%
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
#obs.loc[pst.nnz_obs_names,"standard_deviation"] = 1. / obs.loc[pst.nnz_obs_names,"weight"]
obs = pst.observation_data
obs_times = obs.loc[~obs['gage-1'].isnull(), 'gage-1'].astype(float).values
calib_times = [str(i) for i in obs_times if i<4018.5]
ovals = obs.loc[obs['gage-1'].isin(calib_times), 'obsval']
obs.loc[obs['gage-1'].isin(calib_times), 'weight'] = 1./(ovals*0.01)
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_largerweight"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
# Out:
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 07/30/2021
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Dec 29 2021 09:30:50 with Intel(R) Fortran Intel(R) 64
#    Compiler for applications running on Intel(R) 64, Version 19.1.3.301 Build
#                                 20200925_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:43:06
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:43:07
#  Elapsed run time:  0.595 Seconds
#
#  Normal termination of simulation.
#
# MODPATH Version 7.2.001
# Program compiled Aug 01 2021 12:57:00 with IFORT compiler (ver. 19.10.3)
#
#
# Run particle tracking simulation ...
# Processing Time Step     1 Period     1.  Time =  3.65250E+03  Steady-state flow
# Processing Time Step     1 Period     2.  Time =  3.68350E+03  Steady-state flow
# Processing Time Step     1 Period     3.  Time =  3.71250E+03  Steady-state flow
# Processing Time Step     1 Period     4.  Time =  3.74350E+03  Steady-state flow
# Processing Time Step     1 Period     5.  Time =  3.77350E+03  Steady-state flow
# Processing Time Step     1 Period     6.  Time =  3.80450E+03  Steady-state flow
# Processing Time Step     1 Period     7.  Time =  3.83450E+03  Steady-state flow
# Processing Time Step     1 Period     8.  Time =  3.86550E+03  Steady-state flow
# Processing Time Step     1 Period     9.  Time =  3.89650E+03  Steady-state flow
# Processing Time Step     1 Period    10.  Time =  3.92650E+03  Steady-state flow
# Processing Time Step     1 Period    11.  Time =  3.95750E+03  Steady-state flow
# Processing Time Step     1 Period    12.  Time =  3.98750E+03  Steady-state flow
# Processing Time Step     1 Period    13.  Time =  4.01850E+03  Steady-state flow
# Processing Time Step     1 Period    14.  Time =  4.04950E+03  Steady-state flow
# Processing Time Step     1 Period    15.  Time =  4.07750E+03  Steady-state flow
# Processing Time Step     1 Period    16.  Time =  4.10850E+03  Steady-state flow
# Processing Time Step     1 Period    17.  Time =  4.13850E+03  Steady-state flow
# Processing Time Step     1 Period    18.  Time =  4.16950E+03  Steady-state flow
# Processing Time Step     1 Period    19.  Time =  4.19950E+03  Steady-state flow
# Processing Time Step     1 Period    20.  Time =  4.23050E+03  Steady-state flow
# Processing Time Step     1 Period    21.  Time =  4.26150E+03  Steady-state flow
# Processing Time Step     1 Period    22.  Time =  4.29150E+03  Steady-state flow
# Processing Time Step     1 Period    23.  Time =  4.32250E+03  Steady-state flow
# Processing Time Step     1 Period    24.  Time =  4.35250E+03  Steady-state flow
# Processing Time Step     1 Period    25.  Time =  4.38350E+03  Steady-state flow
#
# Particle Summary:
#          0 particles are pending release.
#          0 particles remain active.
#          0 particles terminated at boundary faces.
#          0 particles terminated at weak sink cells.
#          0 particles terminated at weak source cells.
#          1 particles terminated at strong source/sink cells.
#          0 particles terminated in cells with a specified zone number.
#          0 particles were stranded in inactive or dry cells.
#          0 particles were unreleased.
#          0 particles have an unknown status.
#
# Normal termination.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file heads.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file heads.csv ----->
#  No errors encountered.
#
#  325 observations identified in file heads.csv.ins: these are listed in file
#    heads.csv.obf together with their values as read from file heads.csv.
#
# ins file for heads.csv prepared.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file sfr.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file sfr.csv ----->
#  No errors encountered.
#
#  75 observations identified in file sfr.csv.ins: these are listed in file
#    sfr.csv.obf together with their values as read from file sfr.csv.
#
# ins file for sfr.csv prepared.
# noptmax:0, npar_adj:1, nnz_obs:24
# written pest control file: template/freyberg.pst
# noptmax:6, npar_adj:2, nnz_obs:36
# noptmax:6, npar_adj:2, nnz_obs:36
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.6
# binary compiled on Aug 15 2023 at 16:48:53
#
# started at 11/21/23 15:43:09
# ...processing command line: ' ./pestpp-ies freyberg.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "freyberg.pst"
# in directory: "/Users/mnfienen/Documents/GIT/GMDSI_notebooks/tutorials/part1_06_glm_response_surface/master_largerweight"
# on host: "IGSACB116LHMNFI"
#
# processing control file freyberg.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
#
#   ---  sanity_check warnings  ---
# ...noptmax > 3, this is a lot of iterations for an ensemble method, please consider using fewer iterations for better outcomes
# ...continuing initialization...
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  50
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  50
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  freyberg.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  freyberg.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  freyberg.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 50
#     running model 50 times
#     starting at 11/21/23 15:43:09
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:43:24 mn:0.041 runs(C50   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    50 runs complete :  0 runs failed
#    0.0406 avg run time (min) : 0.252 run mgr time (min)
#    25 agents connected
#
#
# ...saved initial obs ensemble to freyberg.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        28093.5        30938.4        4247.12         134556
#          actual        27968.6        30825.6         4128.6         133850
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        2.79e+04  3.09e+04  4.09e+03  1.34e+05      99.3      1.43
# trgw-0-3-8        43.7      60.7     0.175       415     0.435      1.04
# trgw-0-26-6       34.3      29.9      2.08       149     0.299     0.408
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        28093.5        30938.4        4247.12         134556
#          actual        27968.6        30825.6         4128.6         133850
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        2.79e+04  3.09e+04  4.09e+03  1.34e+05      99.3      1.43
# trgw-0-3-8        43.7      60.7     0.175       415     0.435      1.04
# trgw-0-26-6       34.3      29.9      2.08       149     0.299     0.408
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 100
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  100
# ...starting calcs for glm factor 10
# ...finished calcs for: 10
# ...starting calcs for glm factor 100
# ...finished calcs for: 100
# ...starting calcs for glm factor 1000
# ...finished calcs for: 1000
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  17:17, 21:21, 36:36, 49:BASE,
# ...subset idx:oe real name:  17:17, 21:21, 36:36, 49:BASE,
#     running model 36 times
#     starting at 11/21/23 15:43:25
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:43:34 mn:0.053 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0526 avg run time (min) : 0.144 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  28093.5
# ...last stdev:  30938.4
#
#   ---  phi summary for best lambda, scale fac: 1000 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        4429.32        426.698        3986.85        4989.47
#          actual        4456.95        471.116        3954.78        4989.47
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:1000 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:43:34
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:43:43 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0516 avg run time (min) : 0.154 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 1000 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        5392.09         1039.3        3393.16        7167.24
#          actual        5327.25           1019        3290.44        7150.67
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  29498.1
# ...current best mean phi:  5392.09
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  750  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   50
#    number of model runs:            132
#       current obs ensemble saved to freyberg.1.obs.csv
#       current par ensemble saved to freyberg.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        5392.09         1039.3        3393.16        7167.24
#          actual        5327.25           1019        3290.44        7150.67
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        5.25e+03       980  3.28e+03  7.03e+03      98.6      1.86
# trgw-0-3-8        47.2        84      0.33       548     0.819      1.37
# trgw-0-26-6       32.8      32.3      1.15       218     0.569       0.5
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     22        11         0         0         0         0      0.35       0.4
# rch0                   12        95         0         0         0         0      0.29     0.017
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 ,
# ...best phi yet:  5392.09
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  750
# ...starting calcs for glm factor 75
# ...finished calcs for: 75
# ...starting calcs for glm factor 750
# ...finished calcs for: 750
# ...starting calcs for glm factor 7500
# ...finished calcs for: 7500
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 25:23, 26:24, 46:45,
# ...subset idx:oe real name:  3:BASE, 25:23, 26:24, 46:45,
#     running model 36 times
#     starting at 11/21/23 15:43:43
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:43:52 mn:0.052 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0522 avg run time (min) : 0.145 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  5392.09
# ...last stdev:  1039.3
#
#   ---  phi summary for best lambda, scale fac: 750 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        5174.95        1137.11        4078.66        6211.33
#          actual        5150.03        1140.87        4078.66        6264.37
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:750 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:43:52
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:01 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0513 avg run time (min) : 0.156 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 750 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        5007.79        1249.49        3137.32        8599.92
#          actual        4940.46        1199.21        2995.87        8359.17
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  5661.7
# ...current best mean phi:  5007.79
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   50
#    number of model runs:            214
#       current obs ensemble saved to freyberg.2.obs.csv
#       current par ensemble saved to freyberg.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        5007.79        1249.49        3137.32        8599.92
#          actual        4940.46        1199.21        2995.87        8359.17
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.81e+03  1.05e+03  2.98e+03  7.44e+03      97.8      3.28
# trgw-0-3-8        86.9       168     0.272       643      1.44      2.39
# trgw-0-26-6       43.6      66.7      1.09       279     0.732     0.901
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     42        23         0         0         0         0      0.35      0.47
# rch0                   12        95         0         0         0         0      0.29     0.016
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 , 5007.79 ,
# ...best phi yet:  5007.79
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  750
# ...starting calcs for glm factor 75
# ...finished calcs for: 75
# ...starting calcs for glm factor 750
# ...finished calcs for: 750
# ...starting calcs for glm factor 7500
# ...finished calcs for: 7500
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 9:2, 10:3, 41:39,
# ...subset idx:oe real name:  0:BASE, 9:2, 10:3, 41:39,
#     running model 36 times
#     starting at 11/21/23 15:44:02
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:11 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0508 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  5007.79
# ...last stdev:  1249.49
#
#   ---  phi summary for best lambda, scale fac: 750 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        3635.77        556.439        3152.58         4417.8
#          actual        3663.69        499.795        3272.21        4367.56
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:750 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:44:11
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:20 mn:0.055 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0547 avg run time (min) : 0.159 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 750 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        4746.06         1123.2        2854.83        7728.27
#          actual        4682.26        1061.19        3011.21         7500.8
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  5258.18
# ...current best mean phi:  4746.06
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  562.5  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   50
#    number of model runs:            296
#       current obs ensemble saved to freyberg.3.obs.csv
#       current par ensemble saved to freyberg.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        4746.06         1123.2        2854.83        7728.27
#          actual        4682.26        1061.19        3011.21         7500.8
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.55e+03       921  2.98e+03  6.79e+03      97.5      3.27
# trgw-0-3-8        94.5       154     0.292       515       1.7       2.4
# trgw-0-26-6       42.4      59.2      1.03       211     0.764     0.881
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     52        35         0         0         0         0      0.35      0.48
# rch0                   12        95         0         0         0         0      0.29     0.015
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 , 5007.79 , 4746.06 ,
# ...best phi yet:  4746.06
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 4  ---
# ...current lambda:  562.5
# ...starting calcs for glm factor 56.25
# ...finished calcs for: 56.25
# ...starting calcs for glm factor 562.5
# ...finished calcs for: 562.5
# ...starting calcs for glm factor 5625
# ...finished calcs for: 5625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 8:21, 12:4, 44:42,
# ...subset idx:oe real name:  0:BASE, 8:21, 12:4, 44:42,
#     running model 36 times
#     starting at 11/21/23 15:44:21
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:30 mn:0.056 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0561 avg run time (min) : 0.149 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  4746.06
# ...last stdev:  1123.2
#
#   ---  phi summary for best lambda, scale fac: 562.5 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        4206.43        736.847        3121.51        4763.42
#          actual        4221.96        745.065        3121.51        4767.64
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:562.5 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:44:30
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:40 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0528 avg run time (min) : 0.162 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 562.5 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        4440.26        917.919        2900.76           6493
#          actual        4378.99        865.666        2962.81        6285.71
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  4983.37
# ...current best mean phi:  4440.26
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  421.875  ---
#
#   ---  EnsembleMethod iteration 4 report  ---
#    number of active realizations:   50
#    number of model runs:            378
#       current obs ensemble saved to freyberg.4.obs.csv
#       current par ensemble saved to freyberg.4.par.csv
# saved par and rei files for realization BASE for iteration 4
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        4440.26        917.919        2900.76           6493
#          actual        4378.99        865.666        2962.81        6285.71
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.27e+03       786  2.94e+03  5.85e+03      97.7      2.71
# trgw-0-3-8          79       110     0.364       374      1.62      2.02
# trgw-0-26-6       33.3      39.5      1.04       141     0.675     0.698
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     56        44         0         0         0         0      0.35      0.45
# rch0                   12        95         0         0         0         0      0.29     0.015
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.4.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 , 5007.79 , 4746.06 , 4440.26 ,
# ...best phi yet:  4440.26
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 5  ---
# ...current lambda:  421.875
# ...starting calcs for glm factor 42.1875
# ...finished calcs for: 42.1875
# ...starting calcs for glm factor 421.875
# ...finished calcs for: 421.875
# ...starting calcs for glm factor 4218.75
# ...finished calcs for: 4218.75
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 12:0, 31:26, 49:48,
# ...subset idx:oe real name:  0:BASE, 12:0, 31:26, 49:48,
#     running model 36 times
#     starting at 11/21/23 15:44:40
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:49 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0509 avg run time (min) : 0.144 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  4440.26
# ...last stdev:  917.919
#
#   ---  phi summary for best lambda, scale fac: 4218.75 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        3780.39        722.072        3149.86        4432.39
#          actual        3702.16        694.218        3071.49           4473
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:4218.75 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:44:49
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:44:58 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0518 avg run time (min) : 0.157 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 4218.75 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        4403.72        895.144        2914.01        6346.02
#          actual         4342.6        844.284        2964.59        6140.95
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  4662.27
# ...current best mean phi:  4403.72
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  3164.06  ---
#
#   ---  EnsembleMethod iteration 5 report  ---
#    number of active realizations:   50
#    number of model runs:            460
#       current obs ensemble saved to freyberg.5.obs.csv
#       current par ensemble saved to freyberg.5.par.csv
# saved par and rei files for realization BASE for iteration 5
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        4403.72        895.144        2914.01        6346.02
#          actual         4342.6        844.284        2964.59        6140.95
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.23e+03       770  2.94e+03  5.81e+03      97.7      2.66
# trgw-0-3-8        77.5       106     0.354       366      1.61      1.99
# trgw-0-26-6       32.4      37.9      1.17       137     0.666     0.681
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     57        45         0         0         0         0      0.35      0.44
# rch0                   12        95         0         0         0         0      0.29     0.015
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.5.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 , 5007.79 , 4746.06 , 4440.26 , 4403.72 ,
# ...best phi yet:  4403.72
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 6  ---
# ...current lambda:  3164.06
# ...starting calcs for glm factor 316.406
# ...finished calcs for: 316.406
# ...starting calcs for glm factor 3164.06
# ...finished calcs for: 3164.06
# ...starting calcs for glm factor 31640.6
# ...finished calcs for: 31640.6
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 32:25, 36:30, 45:41,
# ...subset idx:oe real name:  0:BASE, 32:25, 36:30, 45:41,
#     running model 36 times
#     starting at 11/21/23 15:44:58
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:45:07 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0507 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  4403.72
# ...last stdev:  895.144
#
#   ---  phi summary for best lambda, scale fac: 3164.06 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        4243.98        978.334        3255.19         5474.5
#          actual        4117.32        839.101        3255.19        5237.45
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:3164.06 , 1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:45:07
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:45:16 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0509 avg run time (min) : 0.153 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 3164.06 , 1 ,
#        phi type           mean            std            min            max
#        measured        4345.27        866.671        2960.89        6163.53
#          actual        4284.41        818.044           2992        5961.47
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  4623.91
# ...current best mean phi:  4345.27
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  2373.05  ---
#
#   ---  EnsembleMethod iteration 6 report  ---
#    number of active realizations:   50
#    number of model runs:            542
#       current obs ensemble saved to freyberg.6.obs.csv
#       current par ensemble saved to freyberg.6.par.csv
# saved par and rei files for realization BASE for iteration 6
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        4345.27        866.671        2960.89        6163.53
#          actual        4284.41        818.044           2992        5961.47
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.18e+03       749  2.97e+03  5.76e+03      97.7      2.58
# trgw-0-3-8        75.8       101     0.256       355      1.61      1.93
# trgw-0-26-6       31.2      35.7      1.05       132     0.654     0.657
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     58        47         0         0         0         0      0.35      0.44
# rch0                   12        96         0         0         0         0      0.29     0.014
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.6.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5392.09 , 5007.79 , 4746.06 , 4440.26 , 4403.72 , 4345.27 ,
#
# ...best phi yet:  4345.27
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#
# pestpp-ies analysis complete...
# started at 11/21/23 15:43:09
# finished at 11/21/23 15:45:19
# took 2.15 minutes

# %%
plot_ies_and_resp_par_forecast_results(mod_resp_d,m_d)
# Out:
# using iter 6
# (<Figure size 700x700 with 2 Axes>,
#  <Axes: title={'center': 'min $\\Phi$ = 1.95'}, xlabel='$\\beta_1$', ylabel='$\\beta_2$'>)

# %% [markdown]
# Ouch - thats much uglier.  We can see that the trajectory across the response surface suffers from the nonlinearity as the realizations navigate to the trough of dispair, and then just make a sharp change in direction.  #notgood.  Just for fun let's see if the PESTPP-IES multimodal solution process can help here - we will use basically all realizations in the ensemble and simply use the multimodal process to give us a better gradient approximation for each individual realization:

# %%
pst.pestpp_options["ies_multimodal_alpha"] = 0.99        
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_largerweight_mm"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
# Out:
# noptmax:6, npar_adj:2, nnz_obs:36
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.6
# binary compiled on Aug 15 2023 at 16:48:53
#
# started at 11/21/23 15:45:23
# ...processing command line: ' ./pestpp-ies freyberg.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "freyberg.pst"
# in directory: "/Users/mnfienen/Documents/GIT/GMDSI_notebooks/tutorials/part1_06_glm_response_surface/master_largerweight_mm"
# on host: "IGSACB116LHMNFI"
#
# processing control file freyberg.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
#
#   ---  sanity_check warnings  ---
# ...noptmax > 3, this is a lot of iterations for an ensemble method, please consider using fewer iterations for better outcomes
# ...continuing initialization...
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  50
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  50
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  freyberg.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  freyberg.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  freyberg.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 50
#     running model 50 times
#     starting at 11/21/23 15:45:23
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:45:38 mn:0.041 runs(C50   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    50 runs complete :  0 runs failed
#    0.0413 avg run time (min) : 0.249 run mgr time (min)
#    25 agents connected
#
#
# ...saved initial obs ensemble to freyberg.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        28093.5        30938.4        4247.12         134556
#          actual        27968.6        30825.6         4128.6         133850
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        2.79e+04  3.09e+04  4.09e+03  1.34e+05      99.3      1.43
# trgw-0-3-8        43.7      60.7     0.175       415     0.435      1.04
# trgw-0-26-6       34.3      29.9      2.08       149     0.299     0.408
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        28093.5        30938.4        4247.12         134556
#          actual        27968.6        30825.6         4128.6         133850
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        2.79e+04  3.09e+04  4.09e+03  1.34e+05      99.3      1.43
# trgw-0-3-8        43.7      60.7     0.175       415     0.435      1.04
# trgw-0-26-6       34.3      29.9      2.08       149     0.299     0.408
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 100
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  100
# ...starting calcs for glm factor 10
# ...multimodal solve for inflation factor  10
# ...finished calcs for: 10
# ...starting calcs for glm factor 100
# ...multimodal solve for inflation factor  100
# ...finished calcs for: 100
# ...starting calcs for glm factor 1000
# ...multimodal solve for inflation factor  1000
# ...finished calcs for: 1000
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  17:17, 21:21, 36:36, 49:BASE,
# ...subset idx:oe real name:  17:17, 21:21, 36:36, 49:BASE,
#     running model 36 times
#     starting at 11/21/23 15:45:39
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:45:47 mn:0.058 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0579 avg run time (min) : 0.145 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  28093.5
# ...last stdev:  30938.4
#
#   ---  phi summary for best lambda, scale fac: 1000 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        4661.67        595.845        3843.94        5168.04
#          actual        4659.85        566.421        3821.71        5031.28
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:1000 , 1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:45:47
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:45:57 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0523 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 1000 , 1 ,
#        phi type           mean            std            min            max
#        measured        5428.68        829.793        3843.94        8094.11
#          actual        5362.88        788.396        3808.65        7849.73
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  29498.1
# ...current best mean phi:  5428.68
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  750  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   50
#    number of model runs:            132
#       current obs ensemble saved to freyberg.1.obs.csv
#       current par ensemble saved to freyberg.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        5428.68        829.793        3843.94        8094.11
#          actual        5362.88        788.396        3808.65        7849.73
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        5.26e+03       648  3.66e+03  6.96e+03      98.3      2.57
# trgw-0-3-8        64.9       142     0.311       621      1.02      1.87
# trgw-0-26-6       40.3      56.7      2.75       265     0.669     0.711
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     28        38         0         0         0         0      0.35       0.3
# rch0                   11        97         0         0         0         0      0.29     0.011
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5428.68 ,
# ...best phi yet:  5428.68
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  750
# ...starting calcs for glm factor 75
# ...multimodal solve for inflation factor  75
# ...finished calcs for: 75
# ...starting calcs for glm factor 750
# ...multimodal solve for inflation factor  750
# ...finished calcs for: 750
# ...starting calcs for glm factor 7500
# ...multimodal solve for inflation factor  7500
# ...finished calcs for: 7500
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 25:23, 26:24, 46:45,
# ...subset idx:oe real name:  3:BASE, 25:23, 26:24, 46:45,
#     running model 36 times
#     starting at 11/21/23 15:45:57
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:05 mn:0.05  runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0501 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  5428.68
# ...last stdev:  829.793
#
#   ---  phi summary for best lambda, scale fac: 75 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        3220.64        212.278        3013.11        3502.06
#          actual        3199.49        175.299        3059.91        3453.22
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:75 , 1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:46:05
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:15 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0519 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 75 , 1 ,
#        phi type           mean            std            min            max
#        measured        5357.48        2651.59        2989.16        13183.4
#          actual        5303.49        2648.84        2963.14        13347.2
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  5700.12
# ...current best mean phi:  5357.48
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   50
#    number of model runs:            214
#       current obs ensemble saved to freyberg.2.obs.csv
#       current par ensemble saved to freyberg.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        5357.48        2651.59        2989.16        13183.4
#          actual        5303.49        2648.84        2963.14        13347.2
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        4.98e+03  2.26e+03  2.94e+03  1.21e+04      95.8      4.45
# trgw-0-3-8         225       279     0.422       809      2.95      3.11
# trgw-0-26-6         96       125      1.05       388      1.23      1.34
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     70        70         0         0         0         0      0.35      0.34
# rch0                  9.6        94         0         0         0         0      0.29     0.019
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5428.68 , 5357.48 ,
# ...best phi yet:  5357.48
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  750
# ...starting calcs for glm factor 75
# ...multimodal solve for inflation factor  75
# ...finished calcs for: 75
# ...starting calcs for glm factor 750
# ...multimodal solve for inflation factor  750
# ...finished calcs for: 750
# ...starting calcs for glm factor 7500
# ...multimodal solve for inflation factor  7500
# ...finished calcs for: 7500
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 9:2, 10:3, 41:39,
# ...subset idx:oe real name:  0:BASE, 9:2, 10:3, 41:39,
#     running model 36 times
#     starting at 11/21/23 15:46:15
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:23 mn:0.05  runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0501 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  5357.48
# ...last stdev:  2651.59
#
#   ---  phi summary for best lambda, scale fac: 750 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        3389.44        305.147        3012.46         3734.8
#          actual        3423.08        268.332        3150.01        3781.38
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:750 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:46:24
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:33 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0516 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 750 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        3565.51        310.489        3012.46        4294.62
#          actual        3506.95        269.094        3091.25         4096.4
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  5625.35
# ...current best mean phi:  3565.51
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  562.5  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   50
#    number of model runs:            296
#       current obs ensemble saved to freyberg.3.obs.csv
#       current par ensemble saved to freyberg.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        3565.51        310.489        3012.46        4294.62
#          actual        3506.95        269.094        3091.25         4096.4
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        3.48e+03       282  3.08e+03  4.09e+03      99.1      0.85
# trgw-0-3-8        21.5      23.1     0.286      62.4     0.638     0.677
# trgw-0-26-6        7.9      5.93      1.02        18     0.229     0.176
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     61        83         0         0         0         0      0.35      0.15
# rch0                   10        98         0         0         0         0      0.29    0.0071
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5428.68 , 5357.48 , 3565.51 ,
# ...best phi yet:  3565.51
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 4  ---
# ...current lambda:  562.5
# ...starting calcs for glm factor 56.25
# ...multimodal solve for inflation factor  56.25
# ...finished calcs for: 56.25
# ...starting calcs for glm factor 562.5
# ...multimodal solve for inflation factor  562.5
# ...finished calcs for: 562.5
# ...starting calcs for glm factor 5625
# ...multimodal solve for inflation factor  5625
# ...finished calcs for: 5625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 8:21, 12:4, 44:42,
# ...subset idx:oe real name:  0:BASE, 8:21, 12:4, 44:42,
#     running model 36 times
#     starting at 11/21/23 15:46:33
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:42 mn:0.051 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0513 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  3565.51
# ...last stdev:  310.489
#
#   ---  phi summary for best lambda, scale fac: 5625 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        3331.57         64.928        3293.91        3428.51
#          actual        3332.01        68.7402        3270.34        3427.19
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:5625 , 1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:46:42
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:46:51 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0517 avg run time (min) : 0.155 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 5625 , 1 ,
#        phi type           mean            std            min            max
#        measured        3553.43        296.975        2997.31         4244.2
#          actual        3494.39        250.746        3068.69        4043.91
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  3743.79
# ...current best mean phi:  3553.43
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  4218.75  ---
#
#   ---  EnsembleMethod iteration 4 report  ---
#    number of active realizations:   50
#    number of model runs:            378
#       current obs ensemble saved to freyberg.4.obs.csv
#       current par ensemble saved to freyberg.4.par.csv
# saved par and rei files for realization BASE for iteration 4
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        3553.43        296.975        2997.31         4244.2
#          actual        3494.39        250.746        3068.69        4043.91
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        3.46e+03       264  3.06e+03  4.04e+03      99.1     0.857
# trgw-0-3-8        21.9      23.2     0.279      62.3     0.647      0.68
# trgw-0-26-6       7.89      6.02      1.02        18      0.23     0.178
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     61        84         0         0         0         0      0.35      0.15
# rch0                   10        98         0         0         0         0      0.29     0.007
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.4.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5428.68 , 5357.48 , 3565.51 , 3553.43 ,
# ...best phi yet:  3553.43
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 5  ---
# ...current lambda:  4218.75
# ...starting calcs for glm factor 421.875
# ...multimodal solve for inflation factor  421.875
# ...finished calcs for: 421.875
# ...starting calcs for glm factor 4218.75
# ...multimodal solve for inflation factor  4218.75
# ...finished calcs for: 4218.75
# ...starting calcs for glm factor 42187.5
# ...multimodal solve for inflation factor  42187.5
# ...finished calcs for: 42187.5
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 12:0, 31:26, 49:48,
# ...subset idx:oe real name:  0:BASE, 12:0, 31:26, 49:48,
#     running model 36 times
#     starting at 11/21/23 15:46:51
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:00 mn:0.053 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0532 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  3553.43
# ...last stdev:  296.975
#
#   ---  phi summary for best lambda, scale fac: 421.875 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        3315.42        244.274        3075.33        3637.51
#          actual        3248.87         169.56        3075.33        3401.07
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:421.875 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:47:00
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:09 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0528 avg run time (min) : 0.156 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 421.875 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        3413.89        201.127        2896.12        3912.38
#          actual        3355.07        147.528        2978.22        3572.61
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  3731.1
# ...current best mean phi:  3413.89
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  316.406  ---
#
#   ---  EnsembleMethod iteration 5 report  ---
#    number of active realizations:   50
#    number of model runs:            460
#       current obs ensemble saved to freyberg.5.obs.csv
#       current par ensemble saved to freyberg.5.par.csv
# saved par and rei files for realization BASE for iteration 5
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        3413.89        201.127        2896.12        3912.38
#          actual        3355.07        147.528        2978.22        3572.61
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1        3.32e+03       129  2.95e+03   3.5e+03        99     0.913
# trgw-0-3-8        26.3      24.7      1.28      66.9     0.765     0.706
# trgw-0-26-6        8.2      7.25      1.01      18.8     0.239     0.207
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     64        90         0         0         0         0      0.35     0.097
# rch0                   10        98         0         0         0         0      0.29    0.0071
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.5.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 28093.5 , 5428.68 , 5357.48 , 3565.51 , 3553.43 , 3413.89 ,
# ...best phi yet:  3413.89
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 6  ---
# ...current lambda:  316.406
# ...starting calcs for glm factor 31.6406
# ...multimodal solve for inflation factor  31.6406
# ...finished calcs for: 31.6406
# ...starting calcs for glm factor 316.406
# ...multimodal solve for inflation factor  316.406
# ...finished calcs for: 316.406
# ...starting calcs for glm factor 3164.06
# ...multimodal solve for inflation factor  3164.06
# ...finished calcs for: 3164.06
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 32:25, 36:30, 45:41,
# ...subset idx:oe real name:  0:BASE, 32:25, 36:30, 45:41,
#     running model 36 times
#     starting at 11/21/23 15:47:09
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:18 mn:0.053 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0529 avg run time (min) : 0.143 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  3413.89
# ...last stdev:  201.127
#
#   ---  phi summary for best lambda, scale fac: 31.6406 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        3149.87        126.981        3030.03        3307.97
#          actual         3042.8          77.24         2981.9        3154.84
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:31.6406 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:47:18
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:24 mn:0.054 runs(C45   |F0    |T0    ) agents(R1   |W0   |U0   ) 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 4
#       2 pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
#       3 m_d = "master_largerweight_mm"
# ----> 4 pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
#
# File ~/Documents/GIT/GMDSI_notebooks/dependencies/pyemu/pyemu/utils/os_utils.py:353, in start_workers(worker_dir, exe_rel_path, pst_rel_path, num_workers, worker_root, port, rel_path, local, cleanup, master_dir, verbose, silent_master, reuse_master, restart)
#     351         time.sleep(5)
#     352 else:
# --> 353     master_p.wait()
#     354     time.sleep(1.5)  # a few cycles to let the workers end gracefully
#     356 # kill any remaining workers
#
# File ~/opt/miniconda3/envs/gmdsitut/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/opt/miniconda3/envs/gmdsitut/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/opt/miniconda3/envs/gmdsitut/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %%
plot_ies_and_resp_par_forecast_results(mod_resp_d,m_d)

# %% [markdown]
# ### Understanding how noise effects posterior results
#
# Results so far, the noise realizations used in the assimilation process were derived from the assumption that the noise standard deviation was the inverse of the assigned weights.  This is not an ideal situation and in real-world practice (where models are imperfect simulators), we should always seperate the weights and noise.  This can be done in many, many ways.  Herein, we will do this by supplying a `standard_deviation` column in the observation data.  For our first experiement, lets assume the noise standard deviation for groundwater levels is 5.0 and the noise standard deviation for sw flow is 33% of the flow value:

# %%
t_d = "template"
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
hnames = [n for n in pst.nnz_obs_names if "trgw" in n]
gnames = [n for n in pst.nnz_obs_names if "gage" in n]
assert len(hnames) + len(gnames) == pst.nnz_obs
obs.loc[hnames,"standard_deviation"] = 5.0
obs.loc[gnames,"standard_deviation"] = obs.loc[gnames,"obsval"] * 0.33
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_bignoise"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
# Out:
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 07/30/2021
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Dec 29 2021 09:30:50 with Intel(R) Fortran Intel(R) 64
#    Compiler for applications running on Intel(R) 64, Version 19.1.3.301 Build
#                                 20200925_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:47:31
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:47:31
#  Elapsed run time:  0.625 Seconds
#
#  Normal termination of simulation.
#
# MODPATH Version 7.2.001
# Program compiled Aug 01 2021 12:57:00 with IFORT compiler (ver. 19.10.3)
#
#
# Run particle tracking simulation ...
# Processing Time Step     1 Period     1.  Time =  3.65250E+03  Steady-state flow
# Processing Time Step     1 Period     2.  Time =  3.68350E+03  Steady-state flow
# Processing Time Step     1 Period     3.  Time =  3.71250E+03  Steady-state flow
# Processing Time Step     1 Period     4.  Time =  3.74350E+03  Steady-state flow
# Processing Time Step     1 Period     5.  Time =  3.77350E+03  Steady-state flow
# Processing Time Step     1 Period     6.  Time =  3.80450E+03  Steady-state flow
# Processing Time Step     1 Period     7.  Time =  3.83450E+03  Steady-state flow
# Processing Time Step     1 Period     8.  Time =  3.86550E+03  Steady-state flow
# Processing Time Step     1 Period     9.  Time =  3.89650E+03  Steady-state flow
# Processing Time Step     1 Period    10.  Time =  3.92650E+03  Steady-state flow
# Processing Time Step     1 Period    11.  Time =  3.95750E+03  Steady-state flow
# Processing Time Step     1 Period    12.  Time =  3.98750E+03  Steady-state flow
# Processing Time Step     1 Period    13.  Time =  4.01850E+03  Steady-state flow
# Processing Time Step     1 Period    14.  Time =  4.04950E+03  Steady-state flow
# Processing Time Step     1 Period    15.  Time =  4.07750E+03  Steady-state flow
# Processing Time Step     1 Period    16.  Time =  4.10850E+03  Steady-state flow
# Processing Time Step     1 Period    17.  Time =  4.13850E+03  Steady-state flow
# Processing Time Step     1 Period    18.  Time =  4.16950E+03  Steady-state flow
# Processing Time Step     1 Period    19.  Time =  4.19950E+03  Steady-state flow
# Processing Time Step     1 Period    20.  Time =  4.23050E+03  Steady-state flow
# Processing Time Step     1 Period    21.  Time =  4.26150E+03  Steady-state flow
# Processing Time Step     1 Period    22.  Time =  4.29150E+03  Steady-state flow
# Processing Time Step     1 Period    23.  Time =  4.32250E+03  Steady-state flow
# Processing Time Step     1 Period    24.  Time =  4.35250E+03  Steady-state flow
# Processing Time Step     1 Period    25.  Time =  4.38350E+03  Steady-state flow
#
# Particle Summary:
#          0 particles are pending release.
#          0 particles remain active.
#          0 particles terminated at boundary faces.
#          0 particles terminated at weak sink cells.
#          0 particles terminated at weak source cells.
#          1 particles terminated at strong source/sink cells.
#          0 particles terminated in cells with a specified zone number.
#          0 particles were stranded in inactive or dry cells.
#          0 particles were unreleased.
#          0 particles have an unknown status.
#
# Normal termination.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file heads.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file heads.csv ----->
#  No errors encountered.
#
#  325 observations identified in file heads.csv.ins: these are listed in file
#    heads.csv.obf together with their values as read from file heads.csv.
#
# ins file for heads.csv prepared.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file sfr.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file sfr.csv ----->
#  No errors encountered.
#
#  75 observations identified in file sfr.csv.ins: these are listed in file
#    sfr.csv.obf together with their values as read from file sfr.csv.
#
# ins file for sfr.csv prepared.
# noptmax:0, npar_adj:1, nnz_obs:24
# written pest control file: template/freyberg.pst
# noptmax:6, npar_adj:2, nnz_obs:36
# noptmax:6, npar_adj:2, nnz_obs:36
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.6
# binary compiled on Aug 15 2023 at 16:48:53
#
# started at 11/21/23 15:47:33
# ...processing command line: ' ./pestpp-ies freyberg.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "freyberg.pst"
# in directory: "/Users/mnfienen/Documents/GIT/GMDSI_notebooks/tutorials/part1_06_glm_response_surface/master_bignoise"
# on host: "IGSACB116LHMNFI"
#
# processing control file freyberg.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
#
#   ---  sanity_check warnings  ---
# ...noptmax > 3, this is a lot of iterations for an ensemble method, please consider using fewer iterations for better outcomes
# ...continuing initialization...
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  50
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  50
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  freyberg.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  freyberg.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  freyberg.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 50
#     running model 50 times
#     starting at 11/21/23 15:47:33
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:49 mn:0.041 runs(C50   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    50 runs complete :  0 runs failed
#    0.0412 avg run time (min) : 0.259 run mgr time (min)
#    25 agents connected
#
#
# ...saved initial obs ensemble to freyberg.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        1014.19         367.62        115.222        1982.34
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        1014.19         367.62        115.222        1982.34
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  10
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
# ...starting calcs for glm factor 10
# ...finished calcs for: 10
# ...starting calcs for glm factor 100
# ...finished calcs for: 100
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  17:17, 21:21, 36:36, 49:BASE,
# ...subset idx:oe real name:  17:17, 21:21, 36:36, 49:BASE,
#     running model 36 times
#     starting at 11/21/23 15:47:50
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:47:58 mn:0.057 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0573 avg run time (min) : 0.145 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  1014.19
# ...last stdev:  367.62
#
#   ---  phi summary for best lambda, scale fac: 10 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        648.708        429.599        33.5957        1031.88
#          actual        174.436        164.704        32.9347        344.463
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:10 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:47:59
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:08 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0529 avg run time (min) : 0.156 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 10 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        810.729         273.67        33.5957        1510.12
#          actual        164.289        237.155        23.5062        1067.88
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  1064.9
# ...current best mean phi:  810.729
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  7.5  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   50
#    number of model runs:            132
#       current obs ensemble saved to freyberg.1.obs.csv
#       current par ensemble saved to freyberg.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        810.729         273.67        33.5957        1510.12
#          actual        164.289        237.155        23.5062        1067.88
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# trgw-0-3-8        80.9       163     0.416       694      29.2      20.7
# trgw-0-26-6       42.8      67.9      1.05       312      23.4       8.9
# gage-1            40.7      18.4      17.7      90.2      47.4      24.6
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     39        17         0         0         0         0      0.35      0.48
# rch0                   11        72         0         0         0         0      0.29      0.09
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 ,
# ...best phi yet:  810.729
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  7.5
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
# ...starting calcs for glm factor 7.5
# ...finished calcs for: 7.5
# ...starting calcs for glm factor 75
# ...finished calcs for: 75
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 25:23, 26:24, 46:45,
# ...subset idx:oe real name:  3:BASE, 25:23, 26:24, 46:45,
#     running model 36 times
#     starting at 11/21/23 15:48:08
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:17 mn:0.05  runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0498 avg run time (min) : 0.145 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  810.729
# ...last stdev:  273.67
#
#   ---  phi summary for best lambda, scale fac: 7.5 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        645.528        556.599        23.9703        1372.44
#          actual         34.124        15.5011        23.9189        56.6801
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:7.5 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:48:17
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:26 mn:0.054 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0543 avg run time (min) : 0.16 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 7.5 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        748.872        214.659        23.9703        1372.44
#          actual        99.5602        112.805        23.9189        508.444
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  851.265
# ...current best mean phi:  748.872
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  5.625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   50
#    number of model runs:            214
#       current obs ensemble saved to freyberg.2.obs.csv
#       current par ensemble saved to freyberg.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        748.872        214.659        23.9703        1372.44
#          actual        99.5602        112.805        23.9189        508.444
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# trgw-0-3-8        42.3      82.6     0.243       349      24.1      21.5
# gage-1            35.6      16.2      17.8      80.5        57      25.8
# trgw-0-26-6       21.7      28.7       1.3       129      18.9       9.2
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     47        28         0         0         0         0      0.35      0.47
# rch0                   11        73         0         0         0         0      0.29     0.088
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 , 748.872 ,
# ...best phi yet:  748.872
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  5.625
# ...starting calcs for glm factor 0.5625
# ...finished calcs for: 0.5625
# ...starting calcs for glm factor 5.625
# ...finished calcs for: 5.625
# ...starting calcs for glm factor 56.25
# ...finished calcs for: 56.25
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 9:2, 10:3, 41:39,
# ...subset idx:oe real name:  0:BASE, 9:2, 10:3, 41:39,
#     running model 36 times
#     starting at 11/21/23 15:48:27
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:35 mn:0.054 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0537 avg run time (min) : 0.147 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  748.872
# ...last stdev:  214.659
#
#   ---  phi summary for best lambda, scale fac: 5.625 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        478.008         304.48        27.8155        696.736
#          actual        50.7934        30.5879        25.7683        90.6136
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:5.625 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:48:35
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:45 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0534 avg run time (min) : 0.157 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 5.625 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        795.694        267.043        27.8155        1471.83
#          actual        147.017        230.351        23.3813        1025.66
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  786.316
# ...current best mean phi:  795.694
#
#   ---  only updating realizations with reduced phi  ---
# ...current best mean phi (after updating reduced-phi reals):  731.59
#
#   ---  updating lambda to  4.21875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   50
#    number of model runs:            296
#       current obs ensemble saved to freyberg.3.obs.csv
#       current par ensemble saved to freyberg.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured         731.59        204.119        23.9703        1302.57
#          actual        80.2954        81.5867        23.3813        467.988
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            33.4        17      17.4      86.6      59.8      27.1
# trgw-0-3-8        32.6      58.7     0.225       325      25.7      23.2
# trgw-0-26-6       14.2      19.9      1.07       114      14.5      8.13
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     54        36         0         0         0         0      0.35      0.48
# rch0                   11        73         0         0         0         0      0.29     0.089
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 , 748.872 , 731.59 ,
# ...best phi yet:  731.59
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 4  ---
# ...current lambda:  4.21875
# ...starting calcs for glm factor 0.421875
# ...finished calcs for: 0.421875
# ...starting calcs for glm factor 4.21875
# ...finished calcs for: 4.21875
# ...starting calcs for glm factor 42.1875
# ...finished calcs for: 42.1875
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 8:1, 12:5, 44:42,
# ...subset idx:oe real name:  0:BASE, 8:1, 12:5, 44:42,
#     running model 36 times
#     starting at 11/21/23 15:48:45
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:48:55 mn:0.055 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.055 avg run time (min) : 0.162 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  731.59
# ...last stdev:  204.119
#
#   ---  phi summary for best lambda, scale fac: 42.1875 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        524.759        363.854        22.8534        857.943
#          actual        33.8349        15.9733        22.8534         56.728
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:42.1875 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:48:55
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:49:05 mn:0.054 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0535 avg run time (min) : 0.163 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 42.1875 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        716.156          192.6        22.8534        1291.93
#          actual        58.1707        40.3917        22.7428        213.022
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  768.169
# ...current best mean phi:  716.156
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  31.6406  ---
#
#   ---  EnsembleMethod iteration 4 report  ---
#    number of active realizations:   50
#    number of model runs:            378
#       current obs ensemble saved to freyberg.4.obs.csv
#       current par ensemble saved to freyberg.4.par.csv
# saved par and rei files for realization BASE for iteration 4
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        716.156          192.6        22.8534        1291.93
#          actual        58.1707        40.3917        22.7428        213.022
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1              33      16.8      17.7      87.4      68.5      24.9
# trgw-0-3-8        15.8      24.8     0.151       118      18.4      20.1
# trgw-0-26-6       9.42      12.7         1      66.5      13.1      8.64
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     52        39         0         0         0         0      0.35      0.44
# rch0                   11        73         0         0         0         0      0.29     0.088
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.4.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 , 748.872 , 731.59 , 716.156 ,
# ...best phi yet:  716.156
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 5  ---
# ...current lambda:  31.6406
# ...starting calcs for glm factor 3.16406
# ...finished calcs for: 3.16406
# ...starting calcs for glm factor 31.6406
# ...finished calcs for: 31.6406
# ...starting calcs for glm factor 316.406
# ...finished calcs for: 316.406
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 12:3, 31:27, 49:48,
# ...subset idx:oe real name:  0:BASE, 12:3, 31:27, 49:48,
#     running model 36 times
#     starting at 11/21/23 15:49:05
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:49:13 mn:0.052 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.052 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  716.156
# ...last stdev:  192.6
#
#   ---  phi summary for best lambda, scale fac: 316.406 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured         561.93        401.997        22.8292        978.162
#          actual        38.9511        29.8456        22.8292        83.7012
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:316.406 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:49:13
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:49:23 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.053 avg run time (min) : 0.16 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 316.406 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        715.638        191.916        22.8292        1292.14
#          actual        58.5774        40.4028        22.7747        213.752
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  751.964
# ...current best mean phi:  715.638
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  237.305  ---
#
#   ---  EnsembleMethod iteration 5 report  ---
#    number of active realizations:   50
#    number of model runs:            460
#       current obs ensemble saved to freyberg.5.obs.csv
#       current par ensemble saved to freyberg.5.par.csv
# saved par and rei files for realization BASE for iteration 5
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        715.638        191.916        22.8292        1292.14
#          actual        58.5774        40.4028        22.7747        213.752
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            32.9      16.6      17.7      83.6        68        25
# trgw-0-3-8        16.2      24.7     0.154       118      18.9      20.2
# trgw-0-26-6       9.48      12.7         1      66.7      13.2      8.67
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     52        39         0         0         0         0      0.35      0.45
# rch0                   11        73         0         0         0         0      0.29     0.088
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.5.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 , 748.872 , 731.59 , 716.156 , 715.638 ,
# ...best phi yet:  715.638
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 6  ---
# ...current lambda:  237.305
# ...starting calcs for glm factor 23.7305
# ...finished calcs for: 23.7305
# ...starting calcs for glm factor 237.305
# ...finished calcs for: 237.305
# ...starting calcs for glm factor 2373.05
# ...finished calcs for: 2373.05
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 32:26, 36:31, 45:41,
# ...subset idx:oe real name:  0:BASE, 32:26, 36:31, 45:41,
#     running model 36 times
#     starting at 11/21/23 15:49:23
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:49:31 mn:0.052 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0518 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  715.638
# ...last stdev:  191.916
#
#   ---  phi summary for best lambda, scale fac: 23.7305 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        585.852         422.12         22.549        1045.05
#          actual        39.8853         17.638         22.549        64.1667
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:23.7305 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:49:32
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:49:41 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0524 avg run time (min) : 0.162 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 23.7305 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        725.198        199.579         22.549        1294.67
#          actual        75.7807         74.858         22.549        398.104
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  751.42
# ...current best mean phi:  725.198
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  17.7979  ---
#
#   ---  EnsembleMethod iteration 6 report  ---
#    number of active realizations:   50
#    number of model runs:            542
#       current obs ensemble saved to freyberg.6.obs.csv
#       current par ensemble saved to freyberg.6.par.csv
# saved par and rei files for realization BASE for iteration 6
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        725.198        199.579         22.549        1294.67
#          actual        75.7807         74.858         22.549        398.104
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            33.2      16.3      17.3      80.4      63.4      28.7
# trgw-0-3-8        29.4      54.6     0.231       278      22.6      23.7
# trgw-0-26-6       13.2      17.9      1.03      93.3        14      8.72
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     53        36         0         0         0         0      0.35      0.47
# rch0                   11        73         0         0         0         0      0.29     0.088
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.6.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1014.19 , 810.729 , 748.872 , 731.59 , 716.156 , 715.638 , 725.198 ,
#
# ...best phi yet:  715.638
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  1
#
#
# pestpp-ies analysis complete...
# started at 11/21/23 15:47:33
# finished at 11/21/23 15:49:44
# took 2.18333 minutes

# %%
plot_ies_and_resp_par_forecast_results(org_resp_d,m_d)
# Out:
# using iter 6

# %% [markdown]
# Yowza!  Thats a very different result! This spread in the posterior is a direct result of using noisy (aka "perturbed", aka "stochastic") observation values - remember each parameter realization is paired up with a set of these noise obs, so each parameter realization is aiming for different objective function minimum - more noise means bigger differences in realization objective function minima. This is how we explicitly include observation noise in the posterior results...

# %% [markdown]
# ### With multimodal solution
#
# Lets see how the multi-modal solution copes with the high levels of noise:

# %%
t_d = "template"
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
hnames = [n for n in pst.nnz_obs_names if "trgw" in n]
gnames = [n for n in pst.nnz_obs_names if "gage" in n]
assert len(hnames) + len(gnames) == pst.nnz_obs
obs.loc[hnames,"standard_deviation"] = 5.0
obs.loc[gnames,"standard_deviation"] = obs.loc[gnames,"obsval"] * 0.33
pst.pestpp_options["ies_multimodal_alpha"] = 0.99
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_bignoise_mm"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)

# %%
plot_ies_and_resp_par_forecast_results(org_resp_d,m_d)

# %% [markdown]
# ### Less noisy
#
# Just to round-out our analyses, let's get a middle-ground noisy result for comparison:

# %%
t_d = "template"
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
obs = pst.observation_data
hnames = [n for n in pst.nnz_obs_names if "trgw" in n]
gnames = [n for n in pst.nnz_obs_names if "gage" in n]
assert len(hnames) + len(gnames) == pst.nnz_obs
obs.loc[hnames,"standard_deviation"] = 3.0
obs.loc[gnames,"standard_deviation"] = obs.loc[gnames,"obsval"] * 0.25
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_mediumnoise"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)
# Out:
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 07/30/2021
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Dec 29 2021 09:30:50 with Intel(R) Fortran Intel(R) 64
#    Compiler for applications running on Intel(R) 64, Version 19.1.3.301 Build
#                                 20200925_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:52:34
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/11/21 15:52:34
#  Elapsed run time:  0.804 Seconds
#
#  Normal termination of simulation.
#
# MODPATH Version 7.2.001
# Program compiled Aug 01 2021 12:57:00 with IFORT compiler (ver. 19.10.3)
#
#
# Run particle tracking simulation ...
# Processing Time Step     1 Period     1.  Time =  3.65250E+03  Steady-state flow
# Processing Time Step     1 Period     2.  Time =  3.68350E+03  Steady-state flow
# Processing Time Step     1 Period     3.  Time =  3.71250E+03  Steady-state flow
# Processing Time Step     1 Period     4.  Time =  3.74350E+03  Steady-state flow
# Processing Time Step     1 Period     5.  Time =  3.77350E+03  Steady-state flow
# Processing Time Step     1 Period     6.  Time =  3.80450E+03  Steady-state flow
# Processing Time Step     1 Period     7.  Time =  3.83450E+03  Steady-state flow
# Processing Time Step     1 Period     8.  Time =  3.86550E+03  Steady-state flow
# Processing Time Step     1 Period     9.  Time =  3.89650E+03  Steady-state flow
# Processing Time Step     1 Period    10.  Time =  3.92650E+03  Steady-state flow
# Processing Time Step     1 Period    11.  Time =  3.95750E+03  Steady-state flow
# Processing Time Step     1 Period    12.  Time =  3.98750E+03  Steady-state flow
# Processing Time Step     1 Period    13.  Time =  4.01850E+03  Steady-state flow
# Processing Time Step     1 Period    14.  Time =  4.04950E+03  Steady-state flow
# Processing Time Step     1 Period    15.  Time =  4.07750E+03  Steady-state flow
# Processing Time Step     1 Period    16.  Time =  4.10850E+03  Steady-state flow
# Processing Time Step     1 Period    17.  Time =  4.13850E+03  Steady-state flow
# Processing Time Step     1 Period    18.  Time =  4.16950E+03  Steady-state flow
# Processing Time Step     1 Period    19.  Time =  4.19950E+03  Steady-state flow
# Processing Time Step     1 Period    20.  Time =  4.23050E+03  Steady-state flow
# Processing Time Step     1 Period    21.  Time =  4.26150E+03  Steady-state flow
# Processing Time Step     1 Period    22.  Time =  4.29150E+03  Steady-state flow
# Processing Time Step     1 Period    23.  Time =  4.32250E+03  Steady-state flow
# Processing Time Step     1 Period    24.  Time =  4.35250E+03  Steady-state flow
# Processing Time Step     1 Period    25.  Time =  4.38350E+03  Steady-state flow
#
# Particle Summary:
#          0 particles are pending release.
#          0 particles remain active.
#          0 particles terminated at boundary faces.
#          0 particles terminated at weak sink cells.
#          0 particles terminated at weak source cells.
#          1 particles terminated at strong source/sink cells.
#          0 particles terminated in cells with a specified zone number.
#          0 particles were stranded in inactive or dry cells.
#          0 particles were unreleased.
#          0 particles have an unknown status.
#
# Normal termination.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file heads.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file heads.csv ----->
#  No errors encountered.
#
#  325 observations identified in file heads.csv.ins: these are listed in file
#    heads.csv.obf together with their values as read from file heads.csv.
#
# ins file for heads.csv prepared.
#  INSCHEK Version 13.0. Watermark Numerical Computing.
#
#  Errors in file sfr.csv.ins ----->
#  No errors encountered.
#
#  Reading model output file sfr.csv ----->
#  No errors encountered.
#
#  75 observations identified in file sfr.csv.ins: these are listed in file
#    sfr.csv.obf together with their values as read from file sfr.csv.
#
# ins file for sfr.csv prepared.
# noptmax:0, npar_adj:1, nnz_obs:24
# written pest control file: template/freyberg.pst
# noptmax:6, npar_adj:2, nnz_obs:36
# noptmax:6, npar_adj:2, nnz_obs:36
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.6
# binary compiled on Aug 15 2023 at 16:48:53
#
# started at 11/21/23 15:52:37
# ...processing command line: ' ./pestpp-ies freyberg.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "freyberg.pst"
# in directory: "/Users/mnfienen/Documents/GIT/GMDSI_notebooks/tutorials/part1_06_glm_response_surface/master_mediumnoise"
# on host: "IGSACB116LHMNFI"
#
# processing control file freyberg.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
#
#   ---  sanity_check warnings  ---
# ...noptmax > 3, this is a lot of iterations for an ensemble method, please consider using fewer iterations for better outcomes
# ...continuing initialization...
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  50
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  50
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  freyberg.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  freyberg.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  freyberg.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 50
#     running model 50 times
#     starting at 11/21/23 15:52:37
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:52:54 mn:0.044 runs(C50   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    50 runs complete :  0 runs failed
#    0.044 avg run time (min) : 0.284 run mgr time (min)
#    25 agents connected
#
#
# ...saved initial obs ensemble to freyberg.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        571.586        286.312        115.222        1409.37
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        571.586        286.312        115.222        1409.37
#          actual         280.24        226.877        35.7249        1025.54
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1             202       237      28.3  1.01e+03      63.4      27.2
# trgw-0-3-8        43.7      60.7     0.175       415      19.7      16.4
# trgw-0-26-6       34.3      29.9      2.08       149      16.9      11.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 1
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  1
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
# ...starting calcs for glm factor 10
# ...finished calcs for: 10
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  17:17, 21:21, 36:36, 49:BASE,
# ...subset idx:oe real name:  17:17, 21:21, 36:36, 49:BASE,
#     running model 36 times
#     starting at 11/21/23 15:52:55
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:03 mn:0.054 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0538 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  571.586
# ...last stdev:  286.312
#
#   ---  phi summary for best lambda, scale fac: 10 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        317.754        221.724        53.3617        595.503
#          actual        78.2297        61.2837        38.0048        169.564
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:10 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:53:04
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:13 mn:0.053 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0534 avg run time (min) : 0.161 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 10 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        353.522        96.4153        53.3617        636.194
#          actual        91.1674        39.8493        28.6127        169.564
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  600.166
# ...current best mean phi:  353.522
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  7.5  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   50
#    number of model runs:            132
#       current obs ensemble saved to freyberg.1.obs.csv
#       current par ensemble saved to freyberg.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        353.522        96.4153        53.3617        636.194
#          actual        91.1674        39.8493        28.6127        169.564
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            46.1      24.2      21.7       134      55.4      22.2
# trgw-0-3-8          24      21.8     0.333      93.3      22.8      14.1
# trgw-0-26-6       21.1        14      1.14      53.7      21.8      10.7
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     27        26         0         0         0         0      0.35      0.36
# rch0                  7.8        69         0         0         0         0      0.29     0.097
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 ,
# ...best phi yet:  353.522
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  7.5
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
# ...starting calcs for glm factor 7.5
# ...finished calcs for: 7.5
# ...starting calcs for glm factor 75
# ...finished calcs for: 75
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 25:23, 26:24, 46:45,
# ...subset idx:oe real name:  3:BASE, 25:23, 26:24, 46:45,
#     running model 36 times
#     starting at 11/21/23 15:53:13
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:22 mn:0.05  runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.05 avg run time (min) : 0.138 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  353.522
# ...last stdev:  96.4153
#
#   ---  phi summary for best lambda, scale fac: 0.75 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        270.524        216.202        24.4361         550.73
#          actual         35.754        16.6532        24.1271         59.585
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.75 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:53:22
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:31 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0511 avg run time (min) : 0.153 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.75 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        373.995        187.346        24.4361        1116.98
#          actual        124.857        183.272        24.1271        875.995
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  371.198
# ...current best mean phi:  373.995
#
#   ---  only updating realizations with reduced phi  ---
# ...current best mean phi (after updating reduced-phi reals):  314.365
#
#   ---  updating lambda to  0.5625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   50
#    number of model runs:            214
#       current obs ensemble saved to freyberg.2.obs.csv
#       current par ensemble saved to freyberg.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        314.365        90.2957        24.4361        595.503
#          actual        55.7262        33.1324        24.1271        169.564
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            34.2      18.5      18.2       134      68.2      20.6
# trgw-0-3-8        11.8      17.8     0.208      93.3      16.1      15.6
# trgw-0-26-6       9.79      9.94      1.01      44.9      15.6      9.18
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     48        51         0         0         0         0      0.35      0.33
# rch0                  8.7        76         0         0         0         0      0.29     0.077
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 , 314.365 ,
# ...best phi yet:  314.365
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.5625
# ...starting calcs for glm factor 0.05625
# ...finished calcs for: 0.05625
# ...starting calcs for glm factor 0.5625
# ...finished calcs for: 0.5625
# ...starting calcs for glm factor 5.625
# ...finished calcs for: 5.625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 9:5, 10:6, 41:40,
# ...subset idx:oe real name:  3:BASE, 9:5, 10:6, 41:40,
#     running model 36 times
#     starting at 11/21/23 15:53:31
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:39 mn:0.049 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0489 avg run time (min) : 0.14 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  314.365
# ...last stdev:  90.2957
#
#   ---  phi summary for best lambda, scale fac: 5.625 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        199.713        127.273        22.5046        321.928
#          actual        29.9701        5.28122        22.5046         34.669
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:5.625 , 0.75 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:53:40
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:49 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0511 avg run time (min) : 0.152 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 5.625 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        302.873        79.2715        22.5046        519.841
#          actual        49.4992        32.9983        22.5046        149.667
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  330.083
# ...current best mean phi:  302.873
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  4.21875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   50
#    number of model runs:            296
#       current obs ensemble saved to freyberg.3.obs.csv
#       current par ensemble saved to freyberg.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        302.873        79.2715        22.5046        519.841
#          actual        49.4992        32.9983        22.5046        149.667
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            28.7      9.73      18.6      57.3      70.7      23.3
# trgw-0-3-8        12.7      22.4     0.224        95      15.9      18.9
# trgw-0-26-6       8.09      9.55      1.02      45.3      13.5      8.58
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     53        59         0         0         0         0      0.35      0.31
# rch0                  9.9        80         0         0         0         0      0.29     0.064
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 , 314.365 , 302.873 ,
# ...best phi yet:  302.873
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 4  ---
# ...current lambda:  4.21875
# ...starting calcs for glm factor 0.421875
# ...finished calcs for: 0.421875
# ...starting calcs for glm factor 4.21875
# ...finished calcs for: 4.21875
# ...starting calcs for glm factor 42.1875
# ...finished calcs for: 42.1875
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 8:1, 12:7, 44:43,
# ...subset idx:oe real name:  0:BASE, 8:1, 12:7, 44:43,
#     running model 36 times
#     starting at 11/21/23 15:53:49
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:53:57 mn:0.05  runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.05 avg run time (min) : 0.142 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  302.873
# ...last stdev:  79.2715
#
#   ---  phi summary for best lambda, scale fac: 4.21875 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured         231.36        147.186        22.5881        368.658
#          actual        24.7504        1.82446        22.5881        26.5349
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:4.21875 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:53:57
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:54:07 mn:0.054 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0535 avg run time (min) : 0.159 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 4.21875 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        297.522        76.9986        22.5881        500.606
#          actual        46.6662        31.4131        22.5881        169.274
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  318.017
# ...current best mean phi:  297.522
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  3.16406  ---
#
#   ---  EnsembleMethod iteration 4 report  ---
#    number of active realizations:   50
#    number of model runs:            378
#       current obs ensemble saved to freyberg.4.obs.csv
#       current par ensemble saved to freyberg.4.par.csv
# saved par and rei files for realization BASE for iteration 4
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        297.522        76.9986        22.5881        500.606
#          actual        46.6662        31.4131        22.5881        169.274
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            26.7       8.4        18      54.2      69.7      22.9
# trgw-0-3-8        13.1      21.5     0.262       106      18.7      18.8
# trgw-0-26-6       6.86      8.88      1.01      43.5      11.7      7.91
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     57        65         0         0         0         0      0.35      0.28
# rch0                   11        81         0         0         0         0      0.29     0.062
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.4.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 , 314.365 , 302.873 , 297.522 ,
# ...best phi yet:  297.522
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 5  ---
# ...current lambda:  3.16406
# ...starting calcs for glm factor 0.316406
# ...finished calcs for: 0.316406
# ...starting calcs for glm factor 3.16406
# ...finished calcs for: 3.16406
# ...starting calcs for glm factor 31.6406
# ...finished calcs for: 31.6406
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 12:3, 31:27, 49:48,
# ...subset idx:oe real name:  0:BASE, 12:3, 31:27, 49:48,
#     running model 36 times
#     starting at 11/21/23 15:54:07
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:54:16 mn:0.054 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0543 avg run time (min) : 0.147 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  297.522
# ...last stdev:  76.9986
#
#   ---  phi summary for best lambda, scale fac: 3.16406 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured         230.55        152.329        22.5765        387.338
#          actual        30.7487        14.7908        22.5765          52.91
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:3.16406 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:54:16
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:54:25 mn:0.051 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0507 avg run time (min) : 0.156 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 3.16406 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        296.162        75.3467        22.5765        492.691
#          actual        44.2162        30.3216        22.5765        134.857
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  312.398
# ...current best mean phi:  296.162
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  2.37305  ---
#
#   ---  EnsembleMethod iteration 5 report  ---
#    number of active realizations:   50
#    number of model runs:            460
#       current obs ensemble saved to freyberg.5.obs.csv
#       current par ensemble saved to freyberg.5.par.csv
# saved par and rei files for realization BASE for iteration 5
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        296.162        75.3467        22.5765        492.691
#          actual        44.2162        30.3216        22.5765        134.857
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            26.3      8.85      17.7      53.5      72.2      22.4
# trgw-0-3-8          12      21.7     0.311      90.6      17.2      18.4
# trgw-0-26-6       5.92      8.17      1.03      41.8      10.5      7.56
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     57        69         0         0         0         0      0.35      0.26
# rch0                   11        80         0         0         0         0      0.29     0.064
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.5.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 , 314.365 , 302.873 , 297.522 , 296.162 ,
# ...best phi yet:  296.162
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 6  ---
# ...current lambda:  2.37305
# ...starting calcs for glm factor 0.237305
# ...finished calcs for: 0.237305
# ...starting calcs for glm factor 2.37305
# ...finished calcs for: 2.37305
# ...starting calcs for glm factor 23.7305
# ...finished calcs for: 23.7305
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 32:26, 36:31, 45:42,
# ...subset idx:oe real name:  0:BASE, 32:26, 36:31, 45:42,
#     running model 36 times
#     starting at 11/21/23 15:54:25
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:54:34 mn:0.054 runs(C36   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0544 avg run time (min) : 0.145 run mgr time (min)
#    25 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  296.162
# ...last stdev:  75.3467
#
#   ---  phi summary for best lambda, scale fac: 23.7305 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured          251.1        164.164        22.5058        412.341
#          actual        30.8595         9.0909        22.5058        42.9479
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:23.7305 , 1.1 ,   ---
#     running model 46 times
#     starting at 11/21/23 15:54:34
#     25 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/21 15:54:44 mn:0.052 runs(C46   |F0    |T0    ) agents(R0   |W25  |U0   ) 0
#
#    46 runs complete :  0 runs failed
#    0.0517 avg run time (min) : 0.158 run mgr time (min)
#    25 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 23.7305 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        291.435        73.6899        22.5058        490.836
#          actual        39.2217        20.5771        22.5058        129.675
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  310.97
# ...current best mean phi:  291.435
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  17.7979  ---
#
#   ---  EnsembleMethod iteration 6 report  ---
#    number of active realizations:   50
#    number of model runs:            542
#       current obs ensemble saved to freyberg.6.obs.csv
#       current par ensemble saved to freyberg.6.par.csv
# saved par and rei files for realization BASE for iteration 6
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        291.435        73.6899        22.5058        490.836
#          actual        39.2217        20.5771        22.5058        129.675
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group             mean       std       min       max   percent       std
# gage-1            26.2       9.2      17.3      53.2      73.6      19.9
# trgw-0-3-8         8.1        12     0.242        52      15.8      16.6
# trgw-0-26-6       4.95      6.91      1.02      41.9      10.5      7.29
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# hk                     57        70         0         0         0         0      0.35      0.24
# rch0                   11        80         0         0         0         0      0.29     0.065
# rch1                    0         0         0         0         0         0         0         0
# porosity                0         0         0         0         0         0         0         0
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to freyberg.6.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 571.586 , 353.522 , 314.365 , 302.873 , 297.522 , 296.162 , 291.435 ,
#
# ...best phi yet:  291.435
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#
# pestpp-ies analysis complete...
# started at 11/21/23 15:52:37
# finished at 11/21/23 15:54:46
# took 2.15 minutes

# %%
plot_ies_and_resp_par_forecast_results(org_resp_d,m_d)
# Out:
# using iter 6

# %% [markdown]
# Ok now it should be clear - the noise is controlling the posterior variance of both parameters - this is not unexpected in a well-posed inverse problem as both parameters are being strongly conditioned by all the observations.  But in all cases, thought must be put into noise, and, at the very least, weights and noise should be specified explicitly and separately, especially in situations where weights are being adjusted to balance contributions to the objective function.

# %% [markdown]
# ## Bonus material: understanding how ensemble methods cope with non-uniqueness
#
# A major issue in applied groundwater modeling is the inability to uniquely identify all of the uncertain model inputs with the available data.  Using subspace concepts, we would refer to this a large null space and this source of uncertainty is a major contributor to posterior forecast uncertainty.  We saw this in pictures in the original response surface notebook when we graphed the response surface between `hk` and `recharge` when only groundwater level data were being assimilated.  Lets see that again:

# %%
pst = pyemu.Pst(os.path.join(tmp_d,"freyberg.pst"))
obs = pst.observation_data
for grp in pst.nnz_obs_groups:
    if "gage" not in grp:
        continue
    obs.loc[obs.obgnme==grp,"weight"] = 0.0

pst.write(os.path.join(tmp_d, 'freyberg.pst'),version=2)
mod2_resp_d = "resp_weight2"

if os.path.exists(mod2_resp_d):
   shutil.rmtree(mod2_resp_d)
shutil.copytree(tmp_d,mod2_resp_d)
resurf.run_respsurf(par_names=['hk1','rch0'],num_workers=num_workers,port=4269,WORKING_DIR=mod2_resp_d)

# %%
fig, ax, resp_surf = resurf.plot_response_surface(cmap='jet', figsize=(7,7),WORKING_DIR=mod2_resp_d) #maxresp=1e3,

# %% [markdown]
# There is that trough of dispair where combinations of HK and recharge yield simulated groundwater levels that more-or-less reproduce observed groundwater levels.  Lets see how the ensemble smoother copes with this situation:

# %%
t_d = "template"
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
gnames = [n for n in pst.nnz_obs_names if "gage" in n]
obs.loc[gnames,"weight"] = 0.0
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_nonunique"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)

# %%
plot_ies_and_resp_par_forecast_results(mod2_resp_d,m_d)

# %% [markdown]
# Is that what you expected to happen?  Its what we want to happen...The posterior parameter ensemble effectively represents/captures the non-uniqueness, as seen in the parameter histogram plots - the main thing we "learned" by assimilating the groundwater levels is that HK shouldn't be larger than around 10 m/d and that recharge shouldnt be much lower than about 0.9 m/d. Other than that, there are a wide range of HK-recharge combinations that yield a reasonble fit to the observed groundwater levels.  Still, even this modest parameter conditioning has reduced uncetainty for some forecasts as shown in the histogram plots.

# %% [markdown]
# ## Double bonus: experimenting with a realization-local upgrade solution for a highly non-unique inverse problem

# %% [markdown]
# one more time from the top: just for fun, let's run the the multimodal solver on this highly non-unique inverse problem.  Briefly, the multi-modal solver solves the Gauss-Newton upgrade equation for each realization (one by one) and treats each realization as the center of it gradient approximation, rather than using a global mean gradient approximation that is shared across all realizations.
#
# Before running this experiment, try to visualize what you think the individual realization trajectories should look (remembering what the last experiment looked like, what lambda does to the solution trajectory, and how the multimodal solve forms a unique gradient estimate for each realization).  Got it?  Good...

# %%
t_d = "template"
prep_pst(t_d)
pst = pyemu.Pst(os.path.join(t_d,"freyberg.pst"))
obs = pst.observation_data
gnames = [n for n in pst.nnz_obs_names if "gage" in n]
obs.loc[gnames,"weight"] = 0.0
pst.pestpp_options["ies_multimodal_alpha"] = 0.99
pst.write(os.path.join(t_d,"freyberg.pst"),version=2)
m_d = "master_nonunique_mm"
pyemu.os_utils.start_workers(t_d,"pestpp-ies","freyberg.pst",num_workers=num_workers,worker_root=".",master_dir=m_d)

# %%
plot_ies_and_resp_par_forecast_results(mod2_resp_d,m_d)

# %% [markdown]
# Is that what you were expecting?  TBH this is not what I was expecting the first time I ran this experiment - its a little counter-intuitive.  The key piece is to remember that a small lambda value is a more Newton-type solution that can cut across the gradient of the surface, and this, when combined with a more representative local gradient approximation for each realization, allows many realizations to "funnel" in toward the region of objective function minimum.  If you compare these trajectories to the previous experiment, you can see the value of the realization-local gradient approximation - in the previous experiment, all realizations in the lower right quadrant of parameter space essentially moved in the same trajectory (to the upper left), which is the optimal upgrade direction of the ensemble mean.  Whew!
